# %% [markdown]
# # Preprocess Data

# %%
from lang_trans.arabic import buckwalter
import pandas as pd
import numpy as np

# %%
data_input = pd.ExcelFile('data testing arab.xlsx').parse(0)
X_arab = data_input.Arab.to_numpy()
gold_wazan = data_input.wazan.to_numpy()

# %%
X = []
for x in X_arab:
    X.append(buckwalter.transliterate(x))

# %% [markdown]
# # Pattern Extraction

# %%
data = pd.ExcelFile('List Rule_2.xlsx')
excel_files = []
for i in range(1,len(data.sheet_names)):
    file = data.parse(i)
    excel_files.append(file)

# %%
def make_dict(data):
    temp_dict = {}
    for i in range(len(data)):
        temp_dict[data[i]] = i+2
    temp_dict[''] = 1
    return temp_dict

# %%
def make_dictPrefix(data):
    temp_dict = {}
    for i in range(len(data)):
        temp_dict[data[i].split('|')[0]] = i+2
    temp_dict[''] = 1
    return temp_dict

# %%
vectorizer = []

# %%
prefixes = excel_files[len(excel_files)-1].Prefix.to_numpy()
prefixes = sorted(prefixes, key=len,reverse=True)
dict_prefixes = make_dictPrefix(prefixes)
vectorizer.extend(dict_prefixes.keys())
suffixes = excel_files[len(excel_files)-1].Suffix.to_numpy()[:35]
suffixes = sorted(suffixes, key=len,reverse=True)
vectorizer.extend(suffixes)
dict_suffixes = make_dict(suffixes)
dict_infixes = {}
infixes_1 = excel_files[len(excel_files)-1].Infix_1.to_numpy()[:6]
infixes_1 = sorted(infixes_1, key=len,reverse=True)
vectorizer.extend(infixes_1)
dict_infixes[0] = make_dict(infixes_1)
infixes_2 = excel_files[len(excel_files)-1].Infix_2.to_numpy()[:16]
infixes_2 = sorted(infixes_2, key=len,reverse=True)
vectorizer.extend(infixes_2)
dict_infixes[1] = make_dict(infixes_2)
infixes_3 = excel_files[len(excel_files)-1].Infix_3.to_numpy()[:11]
infixes_3 = sorted(infixes_3, key=len,reverse=True)
vectorizer.extend(infixes_3)
dict_infixes[2] = make_dict(infixes_3)
infixes_4 = excel_files[len(excel_files)-1].Infix_4.to_numpy()[:11]
infixes_4 = sorted(infixes_4, key=len,reverse=True)
vectorizer.extend(infixes_4)
dict_infixes[3] = make_dict(infixes_4)
infixes_5 = excel_files[len(excel_files)-1].Infix_5.to_numpy()[:2]
infixes_5 = sorted(infixes_5, key=len,reverse=True)
vectorizer.extend(infixes_5)
dict_infixes[4] = make_dict(infixes_5)
konsonan = excel_files[len(excel_files)-1].konsonan.to_numpy()[:25]
vectorizer.extend(konsonan)
dict_konsonan = make_dict(konsonan)
vectorizer = make_dict(vectorizer)

# %%
del excel_files[-1]

# %%
def prefixExtractor(prefixes,word):
    prefix = ''
    lemma = word
    for d in prefixes:
        preSplit = d.split('|')
        pre = preSplit[0]
        minLength = int(preSplit[1])
        lemmaTemp = word[len(pre):]
        if word.startswith(pre) and len(lemmaTemp) >= minLength:
            prefix = pre
            lemma = lemmaTemp
            break
    return prefix, lemma

# %%
def suffixExtractor(suffixes,word):
    suffix = ''
    lemma = word
    found = False
    for suff in suffixes:
        if word.endswith(suff):
            lemma = word[:len(word)-len(suff)]
            if (len(lemma) >= 6):
                suffix = suff
                found = True
            else:
                 lemma = word
        if found:
            break
    return lemma, suffix

# %%
def infixExtractor(konsonan,word):
    root = []
    infix = word
    for c in word:
        if c in konsonan:
            root.append(c)
            infix = infix.replace(c,'_')
    return infix.split('_')[1:], root

# %%
def vectorizeInfix(dict_infixes,infix,root,dict_konsonan):
    length = len(infix*2)
    v = np.ones(10)
    j = 0
    for i in range(0,length,2):
        v[i] = dict_konsonan[root[j]]
        v[i+1] = dict_infixes[infix[j]]
        j+=1
    return v

# %%
def pattern_extraction(df):
    feature_input = []
    idx = 0
    i = 0
    X_data = []
    for w in df:
        lemma, suffix = suffixExtractor(suffixes,w)
        prefix , lemma2 = prefixExtractor(prefixes,lemma)
        infix, root = infixExtractor(konsonan,lemma2)
        if (len(root) < 3 and suffix != ''):
            root.append(suffix[0]) 
            suffix = ''
        pattern = {'prefix':prefix,'infix':infix,'suffix':suffix,'root':root}
        string_pattern = prefix+'|'+''.join(infix)+'|'+suffix
        X_data.append({'word':w,'pattern':pattern,'string_pattern':string_pattern})
    return X_data

# %%
X_data = pattern_extraction(X)

# %%
testing = pd.ExcelFile('data testing vector.xlsx').parse(0)
testing_X = testing.X.to_numpy()
for i in range(0,len(testing_X)):
    X_data[i]['vector'] = np.fromstring(testing_X[i],sep=' ')

# %%
X_data
# Out:
# [{'word': 'narokaEu',
#   'pattern': {'prefix': 'na',
#    'infix': ['o', 'a', 'u'],
#    'suffix': '',
#    'root': ['r', 'k', 'E']},
#   'string_pattern': 'na|oau|',
#   'vector': array([31., 10.,  7., 22., 14., 18., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>iSodaEo',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'a', 'o'],
#    'suffix': '',
#    'root': ['S', 'd', 'E']},
#   'string_pattern': '>i|oao|',
#   'vector': array([26., 14.,  7.,  8., 14., 18., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'manaEotumaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tumaA',
#    'root': ['m', 'n', 'E']},
#   'string_pattern': '|aao|tumaA',
#   'vector': array([ 1., 24.,  5., 25., 14., 18., 11.,  1.,  1.,  1.,  1.,  4.])},
#  {'word': 'mat~iEiyo',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yo',
#    'root': ['m', 't', 'E']},
#   'string_pattern': '|a~ii|yo',
#   'vector': array([ 1., 24.,  5.,  3., 12., 18., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'ma$okuworuwona',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'u'],
#    'suffix': 'wona',
#    'root': ['$', 'k', 'r']},
#   'string_pattern': 'ma|ouwou|wona',
#   'vector': array([29., 13.,  7., 22.,  9., 10., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'murotad~atayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', '~a'],
#    'suffix': 'tayoni',
#    'root': ['r', 't', 'd']},
#   'string_pattern': 'mu|oa~a|tayoni',
#   'vector': array([30., 10.,  7.,  3., 14.,  8.,  4.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'maqotuwolaAni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'Ani',
#    'root': ['q', 't', 'l']},
#   'string_pattern': 'ma|ouwoa|Ani',
#   'vector': array([29., 21.,  7.,  3.,  9., 23.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'HaAfiZaA',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'A',
#    'root': ['H', 'f', 'Z']},
#   'string_pattern': '|aAia|A',
#   'vector': array([ 1.,  6.,  4., 20., 15., 17.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'Eaz~iro',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~i', 'o'],
#    'suffix': '',
#    'root': ['E', 'z', 'r']},
#   'string_pattern': '|a~io|',
#   'vector': array([ 1., 18.,  5., 11., 12., 10., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'HaAribiyo',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'i'],
#    'suffix': 'yo',
#    'root': ['H', 'r', 'b']},
#   'string_pattern': '|aAii|yo',
#   'vector': array([ 1.,  6.,  4., 10., 15.,  2., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'yanotaqimaAni',
#   'pattern': {'prefix': 'yano',
#    'infix': ['a', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['t', 'q', 'm']},
#   'string_pattern': 'yano|aia|Ani',
#   'vector': array([23.,  3.,  5., 21., 15., 24.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'mu*ab~aHapN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'pN',
#    'root': ['*', 'b', 'H']},
#   'string_pattern': 'mu|a~aa|pN',
#   'vector': array([30.,  9.,  5.,  2., 11.,  6.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': 'basarotumaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tumaA',
#    'root': ['b', 's', 'r']},
#   'string_pattern': '|aao|tumaA',
#   'vector': array([ 1.,  2.,  5., 12., 14., 10., 11.,  1.,  1.,  1.,  1.,  4.])},
#  {'word': 'maqohuworaAtN',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'AtN',
#    'root': ['q', 'h', 'r']},
#   'string_pattern': 'ma|ouwoa|AtN',
#   'vector': array([29., 21.,  7., 26.,  9., 10.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'musotaxorijatayoni',
#   'pattern': {'prefix': 'musota',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'tayoni',
#    'root': ['x', 'r', 'j']},
#   'string_pattern': 'musota|oia|tayoni',
#   'vector': array([ 8.,  7.,  7., 10., 15.,  5.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': '>a$ofiqaA',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'A',
#    'root': ['$', 'f', 'q']},
#   'string_pattern': '>a|oia|A',
#   'vector': array([25., 13.,  7., 20., 15., 21.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'muEojibatayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'tayoni',
#    'root': ['E', 'j', 'b']},
#   'string_pattern': 'mu|oia|tayoni',
#   'vector': array([30., 18.,  7.,  5., 15.,  2.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'yaEoDulaAni',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'u', 'a'],
#    'suffix': 'Ani',
#    'root': ['E', 'D', 'l']},
#   'string_pattern': 'ya|oua|Ani',
#   'vector': array([35., 18.,  7., 15., 17., 23.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'SadaEotun~a',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['S', 'd', 'E']},
#   'string_pattern': '|aao|tun~a',
#   'vector': array([ 1., 14.,  5.,  8., 14., 18., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': 'yaEolamona',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'na',
#    'root': ['E', 'l', 'm']},
#   'string_pattern': 'ya|oao|na',
#   'vector': array([35., 18.,  7., 23., 14., 24., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'takab~arotu',
#   'pattern': {'prefix': 'ta',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'tu',
#    'root': ['k', 'b', 'r']},
#   'string_pattern': 'ta|a~ao|tu',
#   'vector': array([33., 22.,  5.,  2., 11., 10., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': 'munoTaqaAtN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'AtN',
#    'root': ['n', 'T', 'q']},
#   'string_pattern': 'mu|oaa|AtN',
#   'vector': array([30., 25.,  7., 16., 14., 21.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'nusax~iru',
#   'pattern': {'prefix': 'nu',
#    'infix': ['a', '~i', 'u'],
#    'suffix': '',
#    'root': ['s', 'x', 'r']},
#   'string_pattern': 'nu|a~iu|',
#   'vector': array([32., 12.,  5.,  7., 12., 10., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>iEoqaAbFA',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'aA', 'F'],
#    'suffix': 'A',
#    'root': ['E', 'q', 'b']},
#   'string_pattern': '>i|oaAF|A',
#   'vector': array([26., 18.,  7., 21., 10.,  2.,  7.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'SaAbirapN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'pN',
#    'root': ['S', 'b', 'r']},
#   'string_pattern': '|aAia|pN',
#   'vector': array([ 1., 14.,  4.,  2., 15., 10.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': 'HaADiraAni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['H', 'D', 'r']},
#   'string_pattern': '|aAia|Ani',
#   'vector': array([ 1.,  6.,  4., 15., 15., 10.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'EarajuwoA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'u'],
#    'suffix': 'woA',
#    'root': ['E', 'r', 'j']},
#   'string_pattern': '|aau|woA',
#   'vector': array([ 1., 18.,  5., 10., 14.,  5., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': '>adoxilo',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['d', 'x', 'l']},
#   'string_pattern': '>a|oio|',
#   'vector': array([25.,  8.,  7.,  7., 15., 23., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'tarab~aSona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'na',
#    'root': ['r', 'b', 'S']},
#   'string_pattern': 'ta|a~ao|na',
#   'vector': array([33., 10.,  5.,  2., 11., 14., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'AisotiEotaAbFA',
#   'pattern': {'prefix': 'Aisoti',
#    'infix': ['o', 'aA', 'F'],
#    'suffix': 'A',
#    'root': ['E', 't', 'b']},
#   'string_pattern': 'Aisoti|oaAF|A',
#   'vector': array([ 7., 18.,  7.,  3., 10.,  2.,  7.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'Sar~afota',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'ta',
#    'root': ['S', 'r', 'f']},
#   'string_pattern': '|a~ao|ta',
#   'vector': array([ 1., 14.,  5., 10., 11., 20., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'tu$oriqaAni',
#   'pattern': {'prefix': 'tu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['$', 'r', 'q']},
#   'string_pattern': 'tu|oia|Ani',
#   'vector': array([34., 13.,  7., 10., 15., 21.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'salabuwoA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'u'],
#    'suffix': 'woA',
#    'root': ['s', 'l', 'b']},
#   'string_pattern': '|aau|woA',
#   'vector': array([ 1., 12.,  5., 23., 14.,  2., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': 'EaAqiraAtN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'AtN',
#    'root': ['E', 'q', 'r']},
#   'string_pattern': '|aAia|AtN',
#   'vector': array([ 1., 18.,  4., 21., 15., 10.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': '>ilofaHo',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'a', 'o'],
#    'suffix': '',
#    'root': ['l', 'f', 'H']},
#   'string_pattern': '>i|oao|',
#   'vector': array([26., 23.,  7., 20., 14.,  6., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'mutaSad~aqN',
#   'pattern': {'prefix': 'muta',
#    'infix': ['a', '~a', 'N'],
#    'suffix': '',
#    'root': ['S', 'd', 'q']},
#   'string_pattern': 'muta|a~aN|',
#   'vector': array([18., 14.,  5.,  8., 11., 21.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>unofiqu',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['n', 'f', 'q']},
#   'string_pattern': '>u|oiu|',
#   'vector': array([27., 25.,  7., 20., 15., 21., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'saAbitayoni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'yoni',
#    'root': ['s', 'b', 't']},
#   'string_pattern': '|aAia|yoni',
#   'vector': array([ 1., 12.,  4.,  2., 15.,  3.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': '>aEotido',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['E', 't', 'd']},
#   'string_pattern': '>a|oio|',
#   'vector': array([25., 18.,  7.,  3., 15.,  8., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtatolifuwoA',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'i', 'u'],
#    'suffix': 'woA',
#    'root': ['t', 'l', 'f']},
#   'string_pattern': 'laAta|oiu|woA',
#   'vector': array([12.,  3.,  7., 23., 15., 20., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': 'laAtusolifo',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['s', 'l', 'f']},
#   'string_pattern': 'laAtu|oio|',
#   'vector': array([13., 12.,  7., 23., 15., 20., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'tarozuqona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'u', 'o'],
#    'suffix': 'na',
#    'root': ['r', 'z', 'q']},
#   'string_pattern': 'ta|ouo|na',
#   'vector': array([33., 10.,  7., 11., 17., 21., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'marohuwobiyona',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'i'],
#    'suffix': 'yona',
#    'root': ['r', 'h', 'b']},
#   'string_pattern': 'ma|ouwoi|yona',
#   'vector': array([29., 10.,  7., 26.,  9.,  2., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'laAtufan~idiyo',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yo',
#    'root': ['f', 'n', 'd']},
#   'string_pattern': 'laAtu|a~ii|yo',
#   'vector': array([13., 20.,  5., 25., 12.,  8., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'faS~alona',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'na',
#    'root': ['f', 'S', 'l']},
#   'string_pattern': '|a~ao|na',
#   'vector': array([ 1., 20.,  5., 14., 11., 23., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'maTomuwosayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['T', 'm', 's']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 16.,  7., 24.,  9., 12.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'nasafato',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': 'to',
#    'root': ['n', 's', 'f']},
#   'string_pattern': '|aaa|to',
#   'vector': array([ 1., 25.,  5., 12., 14., 20.,  9.,  1.,  1.,  1.,  1., 25.])},
#  {'word': '>iHosibiyo',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'i', 'i'],
#    'suffix': 'yo',
#    'root': ['H', 's', 'b']},
#   'string_pattern': '>i|oii|yo',
#   'vector': array([26.,  6.,  7., 12., 15.,  2., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'naba*ataA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': 'taA',
#    'root': ['n', 'b', '*']},
#   'string_pattern': '|aaa|taA',
#   'vector': array([ 1., 25.,  5.,  2., 14.,  9.,  9.,  1.,  1.,  1.,  1., 12.])},
#  {'word': 'mafoquwodayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['f', 'q', 'd']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 20.,  7., 21.,  9.,  8.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'tukal~ibiyona',
#   'pattern': {'prefix': 'tu',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yona',
#    'root': ['k', 'l', 'b']},
#   'string_pattern': 'tu|a~ii|yona',
#   'vector': array([34., 22.,  5., 23., 12.,  2., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'munaz~alapN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'pN',
#    'root': ['n', 'z', 'l']},
#   'string_pattern': 'mu|a~aa|pN',
#   'vector': array([30., 25.,  5., 11., 11., 23.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': 'maSoduwoEiyona',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'i'],
#    'suffix': 'yona',
#    'root': ['S', 'd', 'E']},
#   'string_pattern': 'ma|ouwoi|yona',
#   'vector': array([29., 14.,  7.,  8.,  9., 18., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'majonuwobiyona',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'i'],
#    'suffix': 'yona',
#    'root': ['j', 'n', 'b']},
#   'string_pattern': 'ma|ouwoi|yona',
#   'vector': array([29.,  5.,  7., 25.,  9.,  2., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'kaAsibaAtN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'AtN',
#    'root': ['k', 's', 'b']},
#   'string_pattern': '|aAia|AtN',
#   'vector': array([ 1., 22.,  4., 12., 15.,  2.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'yaEomahaAni',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'Ani',
#    'root': ['E', 'm', 'h']},
#   'string_pattern': 'ya|oaa|Ani',
#   'vector': array([35., 18.,  7., 24., 14., 26.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'tuHad~ivaAni',
#   'pattern': {'prefix': 'tu',
#    'infix': ['a', '~i', 'a'],
#    'suffix': 'Ani',
#    'root': ['H', 'd', 'v']},
#   'string_pattern': 'tu|a~ia|Ani',
#   'vector': array([34.,  6.,  5.,  8., 12.,  4.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'tanoTiqaAni',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['n', 'T', 'q']},
#   'string_pattern': 'ta|oia|Ani',
#   'vector': array([33., 25.,  7., 16., 15., 21.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'mutabat~alaAtN',
#   'pattern': {'prefix': 'muta',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'AtN',
#    'root': ['b', 't', 'l']},
#   'string_pattern': 'muta|a~aa|AtN',
#   'vector': array([18.,  2.,  5.,  3., 11., 23.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'baATirN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'N'],
#    'suffix': '',
#    'root': ['b', 'T', 'r']},
#   'string_pattern': '|aAiN|',
#   'vector': array([ 1.,  2.,  4., 16., 15., 10.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAbisaAni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['l', 'b', 's']},
#   'string_pattern': '|aAia|Ani',
#   'vector': array([ 1., 23.,  4.,  2., 15., 12.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': '>axolafotu',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['x', 'l', 'f']},
#   'string_pattern': '>a|oao|tu',
#   'vector': array([25.,  7.,  7., 23., 14., 20., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': 'yamohadona',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'na',
#    'root': ['m', 'h', 'd']},
#   'string_pattern': 'ya|oao|na',
#   'vector': array([35., 24.,  7., 26., 14.,  8., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'musotasoxaraAtN',
#   'pattern': {'prefix': 'musota',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'AtN',
#    'root': ['s', 'x', 'r']},
#   'string_pattern': 'musota|oaa|AtN',
#   'vector': array([ 8., 12.,  7.,  7., 14., 10.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'tatanaz~alaAni',
#   'pattern': {'prefix': 'tata',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'Ani',
#    'root': ['n', 'z', 'l']},
#   'string_pattern': 'tata|a~aa|Ani',
#   'vector': array([22., 25.,  5., 11., 11., 23.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'laAtasotasolimo',
#   'pattern': {'prefix': 'laAtasota',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['s', 'l', 'm']},
#   'string_pattern': 'laAtasota|oio|',
#   'vector': array([ 2., 12.,  7., 23., 15., 24., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'naASiHN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'N'],
#    'suffix': '',
#    'root': ['n', 'S', 'H']},
#   'string_pattern': '|aAiN|',
#   'vector': array([ 1., 25.,  4., 14., 15.,  6.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>unofuxaA',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'u', 'a'],
#    'suffix': 'A',
#    'root': ['n', 'f', 'x']},
#   'string_pattern': '>u|oua|A',
#   'vector': array([27., 25.,  7., 20., 17.,  7.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'Eal~amotumaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'tumaA',
#    'root': ['E', 'l', 'm']},
#   'string_pattern': '|a~ao|tumaA',
#   'vector': array([ 1., 18.,  5., 23., 11., 24., 11.,  1.,  1.,  1.,  1.,  4.])},
#  {'word': 'yataHaAkamaAni',
#   'pattern': {'prefix': 'yata',
#    'infix': ['aA', 'a', 'a'],
#    'suffix': 'Ani',
#    'root': ['H', 'k', 'm']},
#   'string_pattern': 'yata|aAaa|Ani',
#   'vector': array([24.,  6.,  4., 22., 14., 24.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'musotaqodamuwona',
#   'pattern': {'prefix': 'musota',
#    'infix': ['o', 'a', 'u'],
#    'suffix': 'wona',
#    'root': ['q', 'd', 'm']},
#   'string_pattern': 'musota|oau|wona',
#   'vector': array([ 8., 21.,  7.,  8., 14., 24., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'tata*ak~arona',
#   'pattern': {'prefix': 'tata',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'na',
#    'root': ['*', 'k', 'r']},
#   'string_pattern': 'tata|a~ao|na',
#   'vector': array([22.,  9.,  5., 22., 11., 10., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'tukal~ifona',
#   'pattern': {'prefix': 'tu',
#    'infix': ['a', '~i', 'o'],
#    'suffix': 'na',
#    'root': ['k', 'l', 'f']},
#   'string_pattern': 'tu|a~io|na',
#   'vector': array([34., 22.,  5., 23., 12., 20., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'yaboTaraAni',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'Ani',
#    'root': ['b', 'T', 'r']},
#   'string_pattern': 'ya|oaa|Ani',
#   'vector': array([35.,  2.,  7., 16., 14., 10.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'muEa*~irapN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~i', 'a'],
#    'suffix': 'pN',
#    'root': ['E', '*', 'r']},
#   'string_pattern': 'mu|a~ia|pN',
#   'vector': array([30., 18.,  5.,  9., 12., 10.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': 'qaS~iriyo',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yo',
#    'root': ['q', 'S', 'r']},
#   'string_pattern': '|a~ii|yo',
#   'vector': array([ 1., 21.,  5., 14., 12., 10., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'laAtamokuriyo',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'u', 'i'],
#    'suffix': 'yo',
#    'root': ['m', 'k', 'r']},
#   'string_pattern': 'laAta|oui|yo',
#   'vector': array([12., 24.,  7., 22., 17., 10., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': '>uboTuliyo',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'u', 'i'],
#    'suffix': 'yo',
#    'root': ['b', 'T', 'l']},
#   'string_pattern': '>u|oui|yo',
#   'vector': array([27.,  2.,  7., 16., 17., 23., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'laAtuno*irona',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['n', '*', 'r']},
#   'string_pattern': 'laAtu|oio|na',
#   'vector': array([13., 25.,  7.,  9., 15., 10., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'tarodafona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'na',
#    'root': ['r', 'd', 'f']},
#   'string_pattern': 'ta|oao|na',
#   'vector': array([33., 10.,  7.,  8., 14., 20., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'mukal~afatayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'tayoni',
#    'root': ['k', 'l', 'f']},
#   'string_pattern': 'mu|a~aa|tayoni',
#   'vector': array([30., 22.,  5., 23., 11., 20.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'mumohaluwona',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'u'],
#    'suffix': 'wona',
#    'root': ['m', 'h', 'l']},
#   'string_pattern': 'mu|oau|wona',
#   'vector': array([30., 24.,  7., 26., 14., 23., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'marokuwobatayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'tayoni',
#    'root': ['r', 'k', 'b']},
#   'string_pattern': 'ma|ouwoa|tayoni',
#   'vector': array([29., 10.,  7., 22.,  9.,  2.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'xalaqa',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': '',
#    'root': ['x', 'l', 'q']},
#   'string_pattern': '|aaa|',
#   'vector': array([ 1.,  7.,  5., 23., 14., 21.,  9.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'naADijuwona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['n', 'D', 'j']},
#   'string_pattern': '|aAiu|wona',
#   'vector': array([ 1., 25.,  4., 15., 15.,  5., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'qal~abonaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'naA',
#    'root': ['q', 'l', 'b']},
#   'string_pattern': '|a~ao|naA',
#   'vector': array([ 1., 21.,  5., 23., 11.,  2., 11.,  1.,  1.,  1.,  1., 13.])},
#  {'word': 'musotabo$arN',
#   'pattern': {'prefix': 'musota',
#    'infix': ['o', 'a', 'N'],
#    'suffix': '',
#    'root': ['b', '$', 'r']},
#   'string_pattern': 'musota|oaN|',
#   'vector': array([ 8.,  2.,  7., 13., 14., 10.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'haAlikuwona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['h', 'l', 'k']},
#   'string_pattern': '|aAiu|wona',
#   'vector': array([ 1., 26.,  4., 23., 15., 22., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': '>adoHaDotu',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['d', 'H', 'D']},
#   'string_pattern': '>a|oao|tu',
#   'vector': array([25.,  8.,  7.,  6., 14., 15., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': '>iko*ibona',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['k', '*', 'b']},
#   'string_pattern': '>i|oio|na',
#   'vector': array([26., 22.,  7.,  9., 15.,  2., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'munota$irN',
#   'pattern': {'prefix': 'muno',
#    'infix': ['a', 'i', 'N'],
#    'suffix': '',
#    'root': ['t', '$', 'r']},
#   'string_pattern': 'muno|aiN|',
#   'vector': array([17.,  3.,  5., 13., 15., 10.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtataSad~aquwoA',
#   'pattern': {'prefix': 'laAtata',
#    'infix': ['a', '~a', 'u'],
#    'suffix': 'woA',
#    'root': ['S', 'd', 'q']},
#   'string_pattern': 'laAtata|a~au|woA',
#   'vector': array([ 4., 14.,  5.,  8., 11., 21., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': 'maforuwoDiyona',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'i'],
#    'suffix': 'yona',
#    'root': ['f', 'r', 'D']},
#   'string_pattern': 'ma|ouwoi|yona',
#   'vector': array([29., 20.,  7., 10.,  9., 15., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'qanaTotun~a',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['q', 'n', 'T']},
#   'string_pattern': '|aao|tun~a',
#   'vector': array([ 1., 21.,  5., 25., 14., 16., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': '>a$oxaSu',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'u'],
#    'suffix': '',
#    'root': ['$', 'x', 'S']},
#   'string_pattern': '>a|oau|',
#   'vector': array([25., 13.,  7.,  7., 14., 14., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtunoEimiyo',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['o', 'i', 'i'],
#    'suffix': 'yo',
#    'root': ['n', 'E', 'm']},
#   'string_pattern': 'laAtu|oii|yo',
#   'vector': array([13., 25.,  7., 18., 15., 24., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': '>usoquTuwoA',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'u', 'u'],
#    'suffix': 'woA',
#    'root': ['s', 'q', 'T']},
#   'string_pattern': '>u|ouu|woA',
#   'vector': array([27., 12.,  7., 21., 17., 16., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': 'ma$okuworaAtN',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'AtN',
#    'root': ['$', 'k', 'r']},
#   'string_pattern': 'ma|ouwoa|AtN',
#   'vector': array([29., 13.,  7., 22.,  9., 10.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': '>uHaSoHiSu',
#   'pattern': {'prefix': '>u',
#    'infix': ['a', 'o', 'i', 'u'],
#    'suffix': '',
#    'root': ['H', 'S', 'H', 'S']},
#   'string_pattern': '>u|aoiu|',
#   'vector': array([27.,  6.,  5., 14., 16.,  6., 10., 14., 12.,  1.,  1.,  1.])},
#  {'word': 'SadaEonaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'naA',
#    'root': ['S', 'd', 'E']},
#   'string_pattern': '|aao|naA',
#   'vector': array([ 1., 14.,  5.,  8., 14., 18., 11.,  1.,  1.,  1.,  1., 13.])},
#  {'word': 'nuHar~imu',
#   'pattern': {'prefix': 'nu',
#    'infix': ['a', '~i', 'u'],
#    'suffix': '',
#    'root': ['H', 'r', 'm']},
#   'string_pattern': 'nu|a~iu|',
#   'vector': array([32.,  6.,  5., 10., 12., 24., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'damodimona',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['d', 'm', 'd', 'm']},
#   'string_pattern': '|aoio|na',
#   'vector': array([ 1.,  8.,  5., 24., 16.,  8., 10., 24., 11.,  1.,  1., 30.])},
#  {'word': '*aAkiraAni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['*', 'k', 'r']},
#   'string_pattern': '|aAia|Ani',
#   'vector': array([ 1.,  9.,  4., 22., 15., 10.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'qaS~araA',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'A',
#    'root': ['q', 'S', 'r']},
#   'string_pattern': '|a~aa|A',
#   'vector': array([ 1., 21.,  5., 14., 11., 10.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'dam~araA',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'A',
#    'root': ['d', 'm', 'r']},
#   'string_pattern': '|a~aa|A',
#   'vector': array([ 1.,  8.,  5., 24., 11., 10.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'maxoluwoEataAni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'taAni',
#    'root': ['x', 'l', 'E']},
#   'string_pattern': 'ma|ouwoa|taAni',
#   'vector': array([29.,  7.,  7., 23.,  9., 18.,  9.,  1.,  1.,  1.,  1.,  5.])},
#  {'word': 'musotasoxiruwona',
#   'pattern': {'prefix': 'musota',
#    'infix': ['o', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['s', 'x', 'r']},
#   'string_pattern': 'musota|oiu|wona',
#   'vector': array([ 8., 12.,  7.,  7., 15., 10., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'SaniEato',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'i', 'a'],
#    'suffix': 'to',
#    'root': ['S', 'n', 'E']},
#   'string_pattern': '|aia|to',
#   'vector': array([ 1., 14.,  5., 25., 15., 18.,  9.,  1.,  1.,  1.,  1., 25.])},
#  {'word': 'yasofiku',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['s', 'f', 'k']},
#   'string_pattern': 'ya|oiu|',
#   'vector': array([35., 12.,  7., 20., 15., 22., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>usojunaA',
#   'pattern': {'prefix': '',
#    'infix': ['o', 'u'],
#    'suffix': '',
#    'root': ['s', 'j', 'n']},
#   'string_pattern': '|ou|',
#   'vector': array([27., 12.,  7.,  5., 17., 25.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'muDoHakN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'N'],
#    'suffix': '',
#    'root': ['D', 'H', 'k']},
#   'string_pattern': 'mu|oaN|',
#   'vector': array([30., 15.,  7.,  6., 14., 22.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtaboriHuwoA',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'i', 'u'],
#    'suffix': 'woA',
#    'root': ['b', 'r', 'H']},
#   'string_pattern': 'laAta|oiu|woA',
#   'vector': array([12.,  2.,  7., 10., 15.,  6., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': 'muqal~alayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'yoni',
#    'root': ['q', 'l', 'l']},
#   'string_pattern': 'mu|a~aa|yoni',
#   'vector': array([30., 21.,  5., 23., 11., 23.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'tuqaS~iriyona',
#   'pattern': {'prefix': 'tu',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yona',
#    'root': ['q', 'S', 'r']},
#   'string_pattern': 'tu|a~ii|yona',
#   'vector': array([34., 21.,  5., 14., 12., 10., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'muHosanapN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'pN',
#    'root': ['H', 's', 'n']},
#   'string_pattern': 'mu|oaa|pN',
#   'vector': array([30.,  6.,  7., 12., 14., 25.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': 'yuno*iru',
#   'pattern': {'prefix': 'yu',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['n', '*', 'r']},
#   'string_pattern': 'yu|oiu|',
#   'vector': array([36., 25.,  7.,  9., 15., 10., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'faATiruwona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['f', 'T', 'r']},
#   'string_pattern': '|aAiu|wona',
#   'vector': array([ 1., 20.,  4., 16., 15., 10., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'naEolumu',
#   'pattern': {'prefix': 'na',
#    'infix': ['o', 'u', 'u'],
#    'suffix': '',
#    'root': ['E', 'l', 'm']},
#   'string_pattern': 'na|ouu|',
#   'vector': array([31., 18.,  7., 23., 17., 24., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'natolifu',
#   'pattern': {'prefix': 'na',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['t', 'l', 'f']},
#   'string_pattern': 'na|oiu|',
#   'vector': array([31.,  3.,  7., 23., 15., 20., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'taqad~amotun~a',
#   'pattern': {'prefix': 'ta',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['q', 'd', 'm']},
#   'string_pattern': 'ta|a~ao|tun~a',
#   'vector': array([33., 21.,  5.,  8., 11., 24., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': 'mufosadN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'N'],
#    'suffix': '',
#    'root': ['f', 's', 'd']},
#   'string_pattern': 'mu|oaN|',
#   'vector': array([30., 20.,  7., 12., 14.,  8.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'musotakobirataAni',
#   'pattern': {'prefix': 'musota',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'taAni',
#    'root': ['k', 'b', 'r']},
#   'string_pattern': 'musota|oia|taAni',
#   'vector': array([ 8., 22.,  7.,  2., 15., 10.,  9.,  1.,  1.,  1.,  1.,  5.])},
#  {'word': 'mutaraq~abayoni',
#   'pattern': {'prefix': 'muta',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'yoni',
#    'root': ['r', 'q', 'b']},
#   'string_pattern': 'muta|a~aa|yoni',
#   'vector': array([18., 10.,  5., 21., 11.,  2.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'nafaxotun~a',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['n', 'f', 'x']},
#   'string_pattern': '|aao|tun~a',
#   'vector': array([ 1., 25.,  5., 20., 14.,  7., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': '>aSolaHato',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'to',
#    'root': ['S', 'l', 'H']},
#   'string_pattern': '>a|oaa|to',
#   'vector': array([25., 14.,  7., 23., 14.,  6.,  9.,  1.,  1.,  1.,  1., 25.])},
#  {'word': 'TaEanotu',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['T', 'E', 'n']},
#   'string_pattern': '|aao|tu',
#   'vector': array([ 1., 16.,  5., 18., 14., 25., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': '>uEoburaA',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'u', 'a'],
#    'suffix': 'A',
#    'root': ['E', 'b', 'r']},
#   'string_pattern': '>u|oua|A',
#   'vector': array([27., 18.,  7.,  2., 17., 10.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'baAsiriyona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'i'],
#    'suffix': 'yona',
#    'root': ['b', 's', 'r']},
#   'string_pattern': '|aAii|yona',
#   'vector': array([ 1.,  2.,  4., 12., 15., 10., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'yuTaf~ifuwona',
#   'pattern': {'prefix': 'yu',
#    'infix': ['a', '~i', 'u'],
#    'suffix': 'wona',
#    'root': ['T', 'f', 'f']},
#   'string_pattern': 'yu|a~iu|wona',
#   'vector': array([36., 16.,  5., 20., 12., 20., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'AisotaqosamaA',
#   'pattern': {'prefix': 'Aisota',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'A',
#    'root': ['q', 's', 'm']},
#   'string_pattern': 'Aisota|oaa|A',
#   'vector': array([ 6., 21.,  7., 12., 14., 24.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': '>aEoruju',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'u', 'u'],
#    'suffix': '',
#    'root': ['E', 'r', 'j']},
#   'string_pattern': '>a|ouu|',
#   'vector': array([25., 18.,  7., 10., 17.,  5., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'matoruwokayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['t', 'r', 'k']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29.,  3.,  7., 10.,  9., 22.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'muHoSinayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'yoni',
#    'root': ['H', 'S', 'n']},
#   'string_pattern': 'mu|oia|yoni',
#   'vector': array([30.,  6.,  7., 14., 15., 25.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': '>aholakota',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['h', 'l', 'k']},
#   'string_pattern': '>a|oao|ta',
#   'vector': array([25., 26.,  7., 23., 14., 22., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'laAta*okurona',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'u', 'o'],
#    'suffix': 'na',
#    'root': ['*', 'k', 'r']},
#   'string_pattern': 'laAta|ouo|na',
#   'vector': array([12.,  9.,  7., 22., 17., 10., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'laAtujah~izuwoA',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['a', '~i', 'u'],
#    'suffix': 'woA',
#    'root': ['j', 'h', 'z']},
#   'string_pattern': 'laAtu|a~iu|woA',
#   'vector': array([13.,  5.,  5., 26., 12., 11., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': 'muEasoEisataAni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', 'o', 'i', 'a'],
#    'suffix': 'taAni',
#    'root': ['E', 's', 'E', 's']},
#   'string_pattern': 'mu|aoia|taAni',
#   'vector': array([30., 18.,  5., 12., 16., 18., 10., 12.,  9.,  1.,  1.,  5.])},
#  {'word': 'yaEohadu',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'u'],
#    'suffix': '',
#    'root': ['E', 'h', 'd']},
#   'string_pattern': 'ya|oau|',
#   'vector': array([35., 18.,  7., 26., 14.,  8., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>aTomivu',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['T', 'm', 'v']},
#   'string_pattern': '>a|oiu|',
#   'vector': array([25., 16.,  7., 24., 15.,  4., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'muEa*~ariyona',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'i'],
#    'suffix': 'yona',
#    'root': ['E', '*', 'r']},
#   'string_pattern': 'mu|a~ai|yona',
#   'vector': array([30., 18.,  5.,  9., 11., 10., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'fara$otu',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['f', 'r', '$']},
#   'string_pattern': '|aao|tu',
#   'vector': array([ 1., 20.,  5., 10., 14., 13., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': 'muqosaTaAtN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'AtN',
#    'root': ['q', 's', 'T']},
#   'string_pattern': 'mu|oaa|AtN',
#   'vector': array([30., 21.,  7., 12., 14., 16.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'Eamilona',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['E', 'm', 'l']},
#   'string_pattern': '|aio|na',
#   'vector': array([ 1., 18.,  5., 24., 15., 23., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'mutabar~ijN',
#   'pattern': {'prefix': 'muta',
#    'infix': ['a', '~i', 'N'],
#    'suffix': '',
#    'root': ['b', 'r', 'j']},
#   'string_pattern': 'muta|a~iN|',
#   'vector': array([18.,  2.,  5., 10., 12.,  5.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'taHo*ariyona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'a', 'i'],
#    'suffix': 'yona',
#    'root': ['H', '*', 'r']},
#   'string_pattern': 'ta|oai|yona',
#   'vector': array([33.,  6.,  7.,  9., 14., 10., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'xaADiEuwona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['x', 'D', 'E']},
#   'string_pattern': '|aAiu|wona',
#   'vector': array([ 1.,  7.,  4., 15., 15., 18., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'muzolaqiyona',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'i'],
#    'suffix': 'yona',
#    'root': ['z', 'l', 'q']},
#   'string_pattern': 'mu|oai|yona',
#   'vector': array([30., 11.,  7., 23., 14., 21., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'yaSodaEuwona',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'u'],
#    'suffix': 'wona',
#    'root': ['S', 'd', 'E']},
#   'string_pattern': 'ya|oau|wona',
#   'vector': array([35., 14.,  7.,  8., 14., 18., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': '>iqoSimaA',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'A',
#    'root': ['q', 'S', 'm']},
#   'string_pattern': '>i|oia|A',
#   'vector': array([26., 21.,  7., 14., 15., 24.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'Ha$arotumaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tumaA',
#    'root': ['H', '$', 'r']},
#   'string_pattern': '|aao|tumaA',
#   'vector': array([ 1.,  6.,  5., 13., 14., 10., 11.,  1.,  1.,  1.,  1.,  4.])},
#  {'word': 'marojuwofayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['r', 'j', 'f']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 10.,  7.,  5.,  9., 20.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': '>iToEimiyo',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'i', 'i'],
#    'suffix': 'yo',
#    'root': ['T', 'E', 'm']},
#   'string_pattern': '>i|oii|yo',
#   'vector': array([26., 16.,  7., 18., 15., 24., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'laAtalomiso',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['l', 'm', 's']},
#   'string_pattern': 'laAta|oio|',
#   'vector': array([12., 23.,  7., 24., 15., 12., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'muEaj~alayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'yoni',
#    'root': ['E', 'j', 'l']},
#   'string_pattern': 'mu|a~aa|yoni',
#   'vector': array([30., 18.,  5.,  5., 11., 23.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'salakota',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['s', 'l', 'k']},
#   'string_pattern': '|aao|ta',
#   'vector': array([ 1., 12.,  5., 23., 14., 22., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'mumosikaAni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['m', 's', 'k']},
#   'string_pattern': 'mu|oia|Ani',
#   'vector': array([30., 24.,  7., 12., 15., 22.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'faj~ara',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'a'],
#    'suffix': '',
#    'root': ['f', 'j', 'r']},
#   'string_pattern': '|a~aa|',
#   'vector': array([ 1., 20.,  5.,  5., 11., 10.,  9.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'naAqimatayoni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'tayoni',
#    'root': ['n', 'q', 'm']},
#   'string_pattern': '|aAia|tayoni',
#   'vector': array([ 1., 25.,  4., 21., 15., 24.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'mudoHaDatayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'tayoni',
#    'root': ['d', 'H', 'D']},
#   'string_pattern': 'mu|oaa|tayoni',
#   'vector': array([30.,  8.,  7.,  6., 14., 15.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'xaAlaTotun~a',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['x', 'l', 'T']},
#   'string_pattern': '|aAao|tun~a',
#   'vector': array([ 1.,  7.,  4., 23., 14., 16., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': 'laAtuDoHikona',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['D', 'H', 'k']},
#   'string_pattern': 'laAtu|oio|na',
#   'vector': array([13., 15.,  7.,  6., 15., 22., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'tasokutiyona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'u', 'i'],
#    'suffix': 'yona',
#    'root': ['s', 'k', 't']},
#   'string_pattern': 'ta|oui|yona',
#   'vector': array([33., 12.,  7., 22., 17.,  3., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'EaSimotumaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'i', 'o'],
#    'suffix': 'tumaA',
#    'root': ['E', 'S', 'm']},
#   'string_pattern': '|aio|tumaA',
#   'vector': array([ 1., 18.,  5., 14., 15., 24., 11.,  1.,  1.,  1.,  1.,  4.])},
#  {'word': 'samiEa',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'i', 'a'],
#    'suffix': '',
#    'root': ['s', 'm', 'E']},
#   'string_pattern': '|aia|',
#   'vector': array([ 1., 12.,  5., 24., 15., 18.,  9.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'nafarotun~a',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['n', 'f', 'r']},
#   'string_pattern': '|aao|tun~a',
#   'vector': array([ 1., 25.,  5., 20., 14., 10., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': 'masoruwoHuwona',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'u'],
#    'suffix': 'wona',
#    'root': ['s', 'r', 'H']},
#   'string_pattern': 'ma|ouwou|wona',
#   'vector': array([29., 12.,  7., 10.,  9.,  6., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': '>urokumaA',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'u', 'a'],
#    'suffix': 'A',
#    'root': ['r', 'k', 'm']},
#   'string_pattern': '>u|oua|A',
#   'vector': array([27., 10.,  7., 22., 17., 24.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'laAtulozimona',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['l', 'z', 'm']},
#   'string_pattern': 'laAtu|oio|na',
#   'vector': array([13., 23.,  7., 11., 15., 24., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'qal~abona',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'na',
#    'root': ['q', 'l', 'b']},
#   'string_pattern': '|a~ao|na',
#   'vector': array([ 1., 21.,  5., 23., 11.,  2., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': '>asoxaTotu',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['s', 'x', 'T']},
#   'string_pattern': '>a|oao|tu',
#   'vector': array([25., 12.,  7.,  7., 14., 16., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': '>uqonutaA',
#   'pattern': {'prefix': '',
#    'infix': ['o', 'u'],
#    'suffix': '',
#    'root': ['q', 'n', 't']},
#   'string_pattern': '|ou|',
#   'vector': array([27., 21.,  7., 25., 17.,  3.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'tanofu*iyona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'u', 'i'],
#    'suffix': 'yona',
#    'root': ['n', 'f', '*']},
#   'string_pattern': 'ta|oui|yona',
#   'vector': array([33., 25.,  7., 20., 17.,  9., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'laAtaboEavuwoA',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'a', 'u'],
#    'suffix': 'woA',
#    'root': ['b', 'E', 'v']},
#   'string_pattern': 'laAta|oau|woA',
#   'vector': array([12.,  2.,  7., 18., 14.,  4., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': '>akobarota',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['k', 'b', 'r']},
#   'string_pattern': '>a|oao|ta',
#   'vector': array([25., 22.,  7.,  2., 14., 10., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'muxaAlafayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['aA', 'a', 'a'],
#    'suffix': 'yoni',
#    'root': ['x', 'l', 'f']},
#   'string_pattern': 'mu|aAaa|yoni',
#   'vector': array([30.,  7.,  4., 23., 14., 20.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'gaAlibaAni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['g', 'l', 'b']},
#   'string_pattern': '|aAia|Ani',
#   'vector': array([ 1., 19.,  4., 23., 15.,  2.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'maqotuwolayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['q', 't', 'l']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 21.,  7.,  3.,  9., 23.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'taHobaTuwona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'a', 'u'],
#    'suffix': 'wona',
#    'root': ['H', 'b', 'T']},
#   'string_pattern': 'ta|oau|wona',
#   'vector': array([33.,  6.,  7.,  2., 14., 16., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'maHaqato',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': 'to',
#    'root': ['m', 'H', 'q']},
#   'string_pattern': '|aaa|to',
#   'vector': array([ 1., 24.,  5.,  6., 14., 21.,  9.,  1.,  1.,  1.,  1., 25.])},
#  {'word': 'mutabat~ilataAni',
#   'pattern': {'prefix': 'muta',
#    'infix': ['a', '~i', 'a'],
#    'suffix': 'taAni',
#    'root': ['b', 't', 'l']},
#   'string_pattern': 'muta|a~ia|taAni',
#   'vector': array([18.,  2.,  5.,  3., 12., 23.,  9.,  1.,  1.,  1.,  1.,  5.])},
#  {'word': 'tukal~imona',
#   'pattern': {'prefix': 'tu',
#    'infix': ['a', '~i', 'o'],
#    'suffix': 'na',
#    'root': ['k', 'l', 'm']},
#   'string_pattern': 'tu|a~io|na',
#   'vector': array([34., 22.,  5., 23., 12., 24., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'yusal~imaAni',
#   'pattern': {'prefix': 'yu',
#    'infix': ['a', '~i', 'a'],
#    'suffix': 'Ani',
#    'root': ['s', 'l', 'm']},
#   'string_pattern': 'yu|a~ia|Ani',
#   'vector': array([36., 12.,  5., 23., 12., 24.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'taToEanona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'na',
#    'root': ['T', 'E', 'n']},
#   'string_pattern': 'ta|oao|na',
#   'vector': array([33., 16.,  7., 18., 14., 25., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'mufaD~aliyona',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'i'],
#    'suffix': 'yona',
#    'root': ['f', 'D', 'l']},
#   'string_pattern': 'mu|a~ai|yona',
#   'vector': array([30., 20.,  5., 15., 11., 23., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'yafozaEaAni',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'Ani',
#    'root': ['f', 'z', 'E']},
#   'string_pattern': 'ya|oaa|Ani',
#   'vector': array([35., 20.,  7., 11., 14., 18.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'maforuwoTatayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'tayoni',
#    'root': ['f', 'r', 'T']},
#   'string_pattern': 'ma|ouwoa|tayoni',
#   'vector': array([29., 20.,  7., 10.,  9., 16.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'naASiHapN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'pN',
#    'root': ['n', 'S', 'H']},
#   'string_pattern': '|aAia|pN',
#   'vector': array([ 1., 25.,  4., 14., 15.,  6.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': 'muTah~araAni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'Ani',
#    'root': ['T', 'h', 'r']},
#   'string_pattern': 'mu|a~aa|Ani',
#   'vector': array([30., 16.,  5., 26., 11., 10.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'qad~imaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~i', 'a'],
#    'suffix': 'A',
#    'root': ['q', 'd', 'm']},
#   'string_pattern': '|a~ia|A',
#   'vector': array([ 1., 21.,  5.,  8., 12., 24.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'AinotaqamonaA',
#   'pattern': {'prefix': 'Aino',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'naA',
#    'root': ['t', 'q', 'm']},
#   'string_pattern': 'Aino|aao|naA',
#   'vector': array([16.,  3.,  5., 21., 14., 24., 11.,  1.,  1.,  1.,  1., 13.])},
#  {'word': 'faSalotu',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['f', 'S', 'l']},
#   'string_pattern': '|aao|tu',
#   'vector': array([ 1., 20.,  5., 14., 14., 23., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': '$aAgifN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'N'],
#    'suffix': '',
#    'root': ['$', 'g', 'f']},
#   'string_pattern': '|aAiN|',
#   'vector': array([ 1., 13.,  4., 19., 15., 20.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>anogaDataA',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'taA',
#    'root': ['n', 'g', 'D']},
# ...
#   'vector': array([30.,  3.,  7.,  2., 15., 18., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'ma$okuworayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['$', 'k', 'r']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 13.,  7., 22.,  9., 10.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'yukal~ibu',
#   'pattern': {'prefix': 'yu',
#    'infix': ['a', '~i', 'u'],
#    'suffix': '',
#    'root': ['k', 'l', 'b']},
#   'string_pattern': 'yu|a~iu|',
#   'vector': array([36., 22.,  5., 23., 12.,  2., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'tamonaEuwona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'a', 'u'],
#    'suffix': 'wona',
#    'root': ['m', 'n', 'E']},
#   'string_pattern': 'ta|oau|wona',
#   'vector': array([33., 24.,  7., 25., 14., 18., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'makotuwomapN',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'pN',
#    'root': ['k', 't', 'm']},
#   'string_pattern': 'ma|ouwoa|pN',
#   'vector': array([29., 22.,  7.,  3.,  9., 24.,  9.,  1.,  1.,  1.,  1., 28.])},
#  {'word': '>asoqaTota',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['s', 'q', 'T']},
#   'string_pattern': '>a|oao|ta',
#   'vector': array([25., 12.,  7., 21., 14., 16., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'muHobiTataAni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'taAni',
#    'root': ['H', 'b', 'T']},
#   'string_pattern': 'mu|oia|taAni',
#   'vector': array([30.,  6.,  7.,  2., 15., 16.,  9.,  1.,  1.,  1.,  1.,  5.])},
#  {'word': 'xalaSataA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': 'taA',
#    'root': ['x', 'l', 'S']},
#   'string_pattern': '|aaa|taA',
#   'vector': array([ 1.,  7.,  5., 23., 14., 14.,  9.,  1.,  1.,  1.,  1., 12.])},
#  {'word': 'xalaqotumo',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tumo',
#    'root': ['x', 'l', 'q']},
#   'string_pattern': '|aao|tumo',
#   'vector': array([ 1.,  7.,  5., 23., 14., 21., 11.,  1.,  1.,  1.,  1., 10.])},
#  {'word': 'Har~afonaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'naA',
#    'root': ['H', 'r', 'f']},
#   'string_pattern': '|a~ao|naA',
#   'vector': array([ 1.,  6.,  5., 10., 11., 20., 11.,  1.,  1.,  1.,  1., 13.])},
#  {'word': 'yuSobiHu',
#   'pattern': {'prefix': 'yu',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['S', 'b', 'H']},
#   'string_pattern': 'yu|oiu|',
#   'vector': array([36., 14.,  7.,  2., 15.,  6., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'musolafatayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'a', 'a'],
#    'suffix': 'tayoni',
#    'root': ['s', 'l', 'f']},
#   'string_pattern': 'mu|oaa|tayoni',
#   'vector': array([30., 12.,  7., 23., 14., 20.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': '>uEolumuwoA',
#   'pattern': {'prefix': '>u',
#    'infix': ['o', 'u', 'u'],
#    'suffix': 'woA',
#    'root': ['E', 'l', 'm']},
#   'string_pattern': '>u|ouu|woA',
#   'vector': array([27., 18.,  7., 23., 17., 24., 12.,  1.,  1.,  1.,  1., 11.])},
#  {'word': '>ajoramotun~a',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['j', 'r', 'm']},
#   'string_pattern': '>a|oao|tun~a',
#   'vector': array([25.,  5.,  7., 10., 14., 24., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': 'mukaf~alayoni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~a', 'a'],
#    'suffix': 'yoni',
#    'root': ['k', 'f', 'l']},
#   'string_pattern': 'mu|a~aa|yoni',
#   'vector': array([30., 22.,  5., 20., 11., 23.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'yukal~imona',
#   'pattern': {'prefix': 'yu',
#    'infix': ['a', '~i', 'o'],
#    'suffix': 'na',
#    'root': ['k', 'l', 'm']},
#   'string_pattern': 'yu|a~io|na',
#   'vector': array([36., 22.,  5., 23., 12., 24., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'laAtuSar~ifiyo',
#   'pattern': {'prefix': 'laAtu',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yo',
#    'root': ['S', 'r', 'f']},
#   'string_pattern': 'laAtu|a~ii|yo',
#   'vector': array([13., 14.,  5., 10., 12., 20., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'muqosimaAtN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'AtN',
#    'root': ['q', 's', 'm']},
#   'string_pattern': 'mu|oia|AtN',
#   'vector': array([30., 21.,  7., 12., 15., 24.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': 'maHaqataA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': 'taA',
#    'root': ['m', 'H', 'q']},
#   'string_pattern': '|aaa|taA',
#   'vector': array([ 1., 24.,  5.,  6., 14., 21.,  9.,  1.,  1.,  1.,  1., 12.])},
#  {'word': 'HaADiruwona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['H', 'D', 'r']},
#   'string_pattern': '|aAiu|wona',
#   'vector': array([ 1.,  6.,  4., 15., 15., 10., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': '>axorabota',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['x', 'r', 'b']},
#   'string_pattern': '>a|oao|ta',
#   'vector': array([25.,  7.,  7., 10., 14.,  2., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'saraqona',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'na',
#    'root': ['s', 'r', 'q']},
#   'string_pattern': '|aao|na',
#   'vector': array([ 1., 12.,  5., 10., 14., 21., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'munotaqimatayoni',
#   'pattern': {'prefix': 'muno',
#    'infix': ['a', 'i', 'a'],
#    'suffix': 'tayoni',
#    'root': ['t', 'q', 'm']},
#   'string_pattern': 'muno|aia|tayoni',
#   'vector': array([17.,  3.,  5., 21., 15., 24.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'yaHo$uru',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'u', 'u'],
#    'suffix': '',
#    'root': ['H', '$', 'r']},
#   'string_pattern': 'ya|ouu|',
#   'vector': array([35.,  6.,  7., 13., 17., 10., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtanofuxaA',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'u', 'a'],
#    'suffix': 'A',
#    'root': ['n', 'f', 'x']},
#   'string_pattern': 'laAta|oua|A',
#   'vector': array([12., 25.,  7., 20., 17.,  7.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'yugoTi$aAni',
#   'pattern': {'prefix': 'yu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['g', 'T', '$']},
#   'string_pattern': 'yu|oia|Ani',
#   'vector': array([36., 19.,  7., 16., 15., 13.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'faATiriyona',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'i'],
#    'suffix': 'yona',
#    'root': ['f', 'T', 'r']},
#   'string_pattern': '|aAii|yona',
#   'vector': array([ 1., 20.,  4., 16., 15., 10., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'maqoSuwodaAtN',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'AtN',
#    'root': ['q', 'S', 'd']},
#   'string_pattern': 'ma|ouwoa|AtN',
#   'vector': array([29., 21.,  7., 14.,  9.,  8.,  9.,  1.,  1.,  1.,  1., 15.])},
#  {'word': '>asorifo',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['s', 'r', 'f']},
#   'string_pattern': '>a|oio|',
#   'vector': array([25., 12.,  7., 10., 15., 20., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'taEoqiru',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'i', 'u'],
#    'suffix': '',
#    'root': ['E', 'q', 'r']},
#   'string_pattern': 'ta|oiu|',
#   'vector': array([33., 18.,  7., 21., 15., 10., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'marajaA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'a'],
#    'suffix': 'A',
#    'root': ['m', 'r', 'j']},
#   'string_pattern': '|aaa|A',
#   'vector': array([ 1., 24.,  5., 10., 14.,  5.,  9.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'taxoruSuwona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'u', 'u'],
#    'suffix': 'wona',
#    'root': ['x', 'r', 'S']},
#   'string_pattern': 'ta|ouu|wona',
#   'vector': array([33.,  7.,  7., 10., 17., 14., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'yusomiEuwona',
#   'pattern': {'prefix': 'yu',
#    'infix': ['o', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['s', 'm', 'E']},
#   'string_pattern': 'yu|oiu|wona',
#   'vector': array([36., 12.,  7., 24., 15., 18., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': '>arokasotumo',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'tumo',
#    'root': ['r', 'k', 's']},
#   'string_pattern': '>a|oao|tumo',
#   'vector': array([25., 10.,  7., 22., 14., 12., 11.,  1.,  1.,  1.,  1., 10.])},
#  {'word': 'maqohuworayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['q', 'h', 'r']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 21.,  7., 26.,  9., 10.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'manoSuwobayoni',
#   'pattern': {'prefix': 'ma',
#    'infix': ['o', 'uwo', 'a'],
#    'suffix': 'yoni',
#    'root': ['n', 'S', 'b']},
#   'string_pattern': 'ma|ouwoa|yoni',
#   'vector': array([29., 25.,  7., 14.,  9.,  2.,  9.,  1.,  1.,  1.,  1.,  7.])},
#  {'word': 'yaxorujona',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'u', 'o'],
#    'suffix': 'na',
#    'root': ['x', 'r', 'j']},
#   'string_pattern': 'ya|ouo|na',
#   'vector': array([35.,  7.,  7., 10., 17.,  5., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'taEozilaAni',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['E', 'z', 'l']},
#   'string_pattern': 'ta|oia|Ani',
#   'vector': array([33., 18.,  7., 11., 15., 23.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'tu$oEiruwona',
#   'pattern': {'prefix': 'tu',
#    'infix': ['o', 'i', 'u'],
#    'suffix': 'wona',
#    'root': ['$', 'E', 'r']},
#   'string_pattern': 'tu|oiu|wona',
#   'vector': array([34., 13.,  7., 18., 15., 10., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'Aisotagofarota',
#   'pattern': {'prefix': 'Aisota',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['g', 'f', 'r']},
#   'string_pattern': 'Aisota|oao|ta',
#   'vector': array([ 6., 19.,  7., 20., 14., 10., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': 'HaAzinatayoni',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'a'],
#    'suffix': 'tayoni',
#    'root': ['H', 'z', 'n']},
#   'string_pattern': '|aAia|tayoni',
#   'vector': array([ 1.,  6.,  4., 11., 15., 25.,  9.,  1.,  1.,  1.,  1.,  2.])},
#  {'word': 'yaqodumuwona',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'u', 'u'],
#    'suffix': 'wona',
#    'root': ['q', 'd', 'm']},
#   'string_pattern': 'ya|ouu|wona',
#   'vector': array([35., 21.,  7.,  8., 17., 24., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'yagonamu',
#   'pattern': {'prefix': 'ya',
#    'infix': ['o', 'a', 'u'],
#    'suffix': '',
#    'root': ['g', 'n', 'm']},
#   'string_pattern': 'ya|oau|',
#   'vector': array([35., 19.,  7., 25., 14., 24., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'baTanotu',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['b', 'T', 'n']},
#   'string_pattern': '|aao|tu',
#   'vector': array([ 1.,  2.,  5., 16., 14., 25., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': 'yuhoTiEaAni',
#   'pattern': {'prefix': 'yu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['h', 'T', 'E']},
#   'string_pattern': 'yu|oia|Ani',
#   'vector': array([36., 26.,  7., 16., 15., 18.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': 'taforuguwona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'u', 'u'],
#    'suffix': 'wona',
#    'root': ['f', 'r', 'g']},
#   'string_pattern': 'ta|ouu|wona',
#   'vector': array([33., 20.,  7., 10., 17., 19., 12.,  1.,  1.,  1.,  1.,  9.])},
#  {'word': 'laAtaqoniTiyo',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'i', 'i'],
#    'suffix': 'yo',
#    'root': ['q', 'n', 'T']},
#   'string_pattern': 'laAta|oii|yo',
#   'vector': array([12., 21.,  7., 25., 15., 16., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'taSobiyoHF',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'iyo', 'F'],
#    'suffix': '',
#    'root': ['S', 'b', 'H']},
#   'string_pattern': 'ta|oiyoF|',
#   'vector': array([33., 14.,  7.,  2.,  8.,  6.,  7.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>iEobisona',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['E', 'b', 's']},
#   'string_pattern': '>i|oio|na',
#   'vector': array([26., 18.,  7.,  2., 15., 12., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'tagosilona',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'i', 'o'],
#    'suffix': 'na',
#    'root': ['g', 's', 'l']},
#   'string_pattern': 'ta|oio|na',
#   'vector': array([33., 19.,  7., 12., 15., 23., 11.,  1.,  1.,  1.,  1., 30.])},
#  {'word': 'muvab~iTiyona',
#   'pattern': {'prefix': 'mu',
#    'infix': ['a', '~i', 'i'],
#    'suffix': 'yona',
#    'root': ['v', 'b', 'T']},
#   'string_pattern': 'mu|a~ii|yona',
#   'vector': array([30.,  4.,  5.,  2., 12., 16., 10.,  1.,  1.,  1.,  1.,  8.])},
#  {'word': 'tuqat~ilu',
#   'pattern': {'prefix': 'tu',
#    'infix': ['a', '~i', 'u'],
#    'suffix': '',
#    'root': ['q', 't', 'l']},
#   'string_pattern': 'tu|a~iu|',
#   'vector': array([34., 21.,  5.,  3., 12., 23., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': '>asorafota',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'ta',
#    'root': ['s', 'r', 'f']},
#   'string_pattern': '>a|oao|ta',
#   'vector': array([25., 12.,  7., 10., 14., 20., 11.,  1.,  1.,  1.,  1., 27.])},
#  {'word': '>iqoSaArFA',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'aA', 'F'],
#    'suffix': 'A',
#    'root': ['q', 'S', 'r']},
#   'string_pattern': '>i|oaAF|A',
#   'vector': array([26., 21.,  7., 14., 10., 10.,  7.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'HaSirataA',
#   'pattern': {'prefix': '',
#    'infix': ['a', 'i', 'a'],
#    'suffix': 'taA',
#    'root': ['H', 'S', 'r']},
#   'string_pattern': '|aia|taA',
#   'vector': array([ 1.,  6.,  5., 14., 15., 10.,  9.,  1.,  1.,  1.,  1., 12.])},
#  {'word': 'musokinaAni',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'a'],
#    'suffix': 'Ani',
#    'root': ['s', 'k', 'n']},
#   'string_pattern': 'mu|oia|Ani',
#   'vector': array([30., 12.,  7., 22., 15., 25.,  9.,  1.,  1.,  1.,  1., 16.])},
#  {'word': '>anoqa*otu',
#   'pattern': {'prefix': '>a',
#    'infix': ['o', 'a', 'o'],
#    'suffix': 'tu',
#    'root': ['n', 'q', '*']},
#   'string_pattern': '>a|oao|tu',
#   'vector': array([25., 25.,  7., 21., 14.,  9., 11.,  1.,  1.,  1.,  1., 24.])},
#  {'word': '>iloHaAqFA',
#   'pattern': {'prefix': '>i',
#    'infix': ['o', 'aA', 'F'],
#    'suffix': 'A',
#    'root': ['l', 'H', 'q']},
#   'string_pattern': '>i|oaAF|A',
#   'vector': array([26., 23.,  7.,  6., 10., 21.,  7.,  1.,  1.,  1.,  1., 34.])},
#  {'word': 'taxoludu',
#   'pattern': {'prefix': 'ta',
#    'infix': ['o', 'u', 'u'],
#    'suffix': '',
#    'root': ['x', 'l', 'd']},
#   'string_pattern': 'ta|ouu|',
#   'vector': array([33.,  7.,  7., 23., 17.,  8., 12.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtaforiHo',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'i', 'o'],
#    'suffix': '',
#    'root': ['f', 'r', 'H']},
#   'string_pattern': 'laAta|oio|',
#   'vector': array([12., 20.,  7., 10., 15.,  6., 11.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'Eaj~alotun~a',
#   'pattern': {'prefix': '',
#    'infix': ['a', '~a', 'o'],
#    'suffix': 'tun~a',
#    'root': ['E', 'j', 'l']},
#   'string_pattern': '|a~ao|tun~a',
#   'vector': array([ 1., 18.,  5.,  5., 11., 23., 11.,  1.,  1.,  1.,  1.,  3.])},
#  {'word': '$aAriHN',
#   'pattern': {'prefix': '',
#    'infix': ['aA', 'i', 'N'],
#    'suffix': '',
#    'root': ['$', 'r', 'H']},
#   'string_pattern': '|aAiN|',
#   'vector': array([ 1., 13.,  4., 10., 15.,  6.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'mubolisN',
#   'pattern': {'prefix': 'mu',
#    'infix': ['o', 'i', 'N'],
#    'suffix': '',
#    'root': ['b', 'l', 's']},
#   'string_pattern': 'mu|oiN|',
#   'vector': array([30.,  2.,  7., 23., 15., 12.,  8.,  1.,  1.,  1.,  1.,  1.])},
#  {'word': 'laAtaqoTaEiyo',
#   'pattern': {'prefix': 'laAta',
#    'infix': ['o', 'a', 'i'],
#    'suffix': 'yo',
#    'root': ['q', 'T', 'E']},
#   'string_pattern': 'laAta|oai|yo',
#   'vector': array([12., 21.,  7., 16., 14., 18., 10.,  1.,  1.,  1.,  1., 23.])},
#  {'word': 'nanoHaru',
#   'pattern': {'prefix': 'na',
#    'infix': ['o', 'a', 'u'],
#    'suffix': '',
#    'root': ['n', 'H', 'r']},
#   'string_pattern': 'na|oau|',
#   'vector': array([31., 25.,  7.,  6., 14., 10., 12.,  1.,  1.,  1.,  1.,  1.])},
#  ...]

# %% [markdown]
# # Verb Form Identification

# %%
from keras.models import load_model

# %%
# load model
model = load_model('model.h5')
# summarize model.
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 12, 16)            2880
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 128)               18560
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                1935
# =================================================================
# Total params: 23,375
# Trainable params: 23,375
# Non-trainable params: 0
# _________________________________________________________________

# %%
wazan = ['Iii',
 '(VII) tsulatsy',
 '(IV) tsulatsy',
 '(III) tsulatsy',
 '(X) tsulatsy',
 'Iuu',
 '(VI) tsulatsy',
 '(V) tsulatsy',
 '(IX) tsulatsy',
 'Iaa',
 'Iai',
 'Iia',
 "(I) ruba'iy",
 '(II) tsulatsy',
 'Iau']

# %%
for i in range(0,len(X_data)):
    X_data[i]['wazan'] = gold_wazan[i]
    yhat = model.predict(np.expand_dims(X_data[i]['vector'],0))
    yhat = np.argsort(yhat[0])[-1]
    X_data[i]['wazan_predict'] = wazan[yhat]

# %% [markdown]
# # Pronoun and Type of Word Identification

# %%
wazan_index = [5,11,8,7,14,4,10,9,13,2,1,3,18,6,0]

# %%
import string
def trim_space(strng):
    return strng.translate({ord(c): None for c in string.whitespace})

# %%
def extract_pronoun_tow(excel_file):
    excel_file_numpy = excel_file.to_numpy()
    type_of_words = list(excel_file.columns.values)
    dict_pattern = {}
    for i in range(0,excel_file_numpy.shape[0]):
        pron = excel_file_numpy[i][excel_file_numpy.shape[1]-1]
        for j in range(0,excel_file_numpy.shape[1]-1):
            tow = type_of_words[j]
            pattern =  excel_file_numpy[i][j]
            if (type(pattern) == str):
                pattern = trim_space(pattern)
                if ('/'  in pattern):
                    for p in pattern.split('/'):
                        dict_pattern[p] = [pron,tow]
                else:
                    dict_pattern[pattern] = [pron,tow]
    return dict_pattern

# %%
dict_wazan_pattern = {}
for i in range(0,len(wazan)):
    dict_wazan_pattern[wazan[i]] = extract_pronoun_tow(excel_files[wazan_index[i]])

# %%
dict_wazan_pattern
# Out:
# {'Iii': {'ma|ouwoN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ya|oiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aia|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ya|oia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aia|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwou|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoi|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   '|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'ya|oiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aiu|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'ta|oiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aia|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ta|oia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aia|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'ya|oio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAta|oio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '>i|oio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aio|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAta|oia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '>i|oia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aio|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAta|oiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '>i|oiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'ta|oiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAta|oii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '>i|oii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'ta|oii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAta|oio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '>i|oio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'ta|oio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|oiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aio|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|oiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(VII) tsulatsy': {'muno|aaN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'Aino|iaAF|A': ['هُوَ', 'مَصْدَرْ'],
#   'yano|aiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'muno|aaa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aaa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'muno|aia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yano|aia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'muno|aau|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'muno|aii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yano|aiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'muno|aaa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tano|aiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'muno|aaa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aaa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'muno|aia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tano|aia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'muno|aaa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'muno|aia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yano|aio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtano|aio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   'Aino|aio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   'Aino|aao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtano|aia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   'Aino|aia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   'Aino|aao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtano|aiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   'Aino|aiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tano|aiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtano|aii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   'Aino|aii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tano|aii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtano|aio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   'Aino|aio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tano|aio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>ano|aiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nano|aiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   'Aino|aao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(IV) tsulatsy': {'mu|oaN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   '>i|oaAF|A': ['هُوَ', 'مَصْدَرْ'],
#   'yu|oiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'mu|oaa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oaa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|oia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yu|oia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '>a|oaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|oau|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'mu|oii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yu|oiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'mu|oaa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tu|oiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'mu|oaa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oaa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|oia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tu|oia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '>a|oaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|oaa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|oia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yu|oio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtu|oio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '>a|oio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '>a|oao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtu|oia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '>a|oia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '>a|oao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtu|oiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '>a|oiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tu|oiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtu|oii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '>a|oii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tu|oii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtu|oio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '>a|oio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tu|oio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>u|oiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '>a|oao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nu|oiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '>a|oao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(III) tsulatsy': {'mu|aAaN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'mu|aAaa|pF': ['هُوَ', 'مَصْدَرْ'],
#   'yu|aAiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aAaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'mu|aAaa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAaa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yu|aAia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aAaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|aAau|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'mu|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yu|aAiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aAau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'mu|aAaa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tu|aAiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aAaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'mu|aAaa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAaa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tu|aAia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aAaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|aAaa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yu|aAio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aAao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtu|aAio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '|aAio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aAao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtu|aAia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '|aAia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aAao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtu|aAiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '|aAiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tu|aAiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aAao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtu|aAii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '|aAii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tu|aAii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aAao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtu|aAio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '|aAio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tu|aAio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aAao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>u|aAiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aAao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nu|aAiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aAao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(X) tsulatsy': {'musota|oaN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'Aisoti|oaAF|A': ['هُوَ', 'مَصْدَرْ'],
#   'yasota|oiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'musota|oaa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oaa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'musota|oia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yasota|oia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'musota|oau|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'musota|oii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yasota|oiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'musota|oaa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tasota|oiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'musota|oaa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oaa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'musota|oia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tasota|oia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'musota|oaa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'musota|oia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yasota|oio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtasota|oio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   'Aisota|oio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   'Aisota|oao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtasota|oia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   'Aisota|oia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   'Aisota|oao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtasota|oiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   'Aisota|oiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tasota|oiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtasota|oii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   'Aisota|oii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tasota|oii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtasota|oio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   'Aisota|oio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tasota|oio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>asota|oiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nasota|oiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   'Aisota|oao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  'Iuu': {'ya|ouu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aua|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'ya|oua|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aua|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ya|ouu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|auu|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'ta|ouu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aua|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'ta|oua|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aua|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ya|ouo|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|auo|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   '|auo|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   '|auo|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'ta|ouu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|auo|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'ta|oui|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|auo|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'ta|ouo|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|auo|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|ouu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|auo|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|ouu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|auo|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(VI) tsulatsy': {'muta|aAaN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ta|aAuF|A': ['هُوَ', 'مَصْدَرْ'],
#   'yata|aAau|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'muta|aAaa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAaa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'muta|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yata|aAaa|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'muta|aAau|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'muta|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yata|aAau|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'muta|aAaa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tata|aAau|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'muta|aAaa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAaa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'muta|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tata|aAaa|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'muta|aAaa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yata|aAao|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~ao|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   'ta|a~ao|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   'ta|aAao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~aa|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   'ta|a~aa|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   'ta|aAao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtata|a~au|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   'ta|a~au|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tata|aAau|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~ai|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   'ta|a~ai|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tata|aAai|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~ao|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   'ta|a~ao|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tata|aAao|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>ata|aAau|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nata|a~au|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   'ta|aAao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(V) tsulatsy': {'muta|a~aN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~iN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ta|a~uF|': ['هُوَ', 'مَصْدَرْ'],
#   'yata|a~au|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~aa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'muta|a~aa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~aa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~ia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'muta|a~ia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yata|a~aa|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~aa|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   'muta|a~au|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~ai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~iu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'muta|a~ii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yata|a~au|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~au|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'muta|a~aa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~ia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tata|a~au|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~aa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'muta|a~aa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~aa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~ia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'muta|a~ia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tata|a~aa|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~aa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'muta|a~aa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'muta|a~ia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yata|a~ao|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~ao|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'laAtata|a~ao|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   'ta|a~ao|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   'ta|a~ao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~aa|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   'ta|a~ao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtata|a~au|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   'tata|a~au|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~ao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~ai|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   'ta|a~ai|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tata|a~ai|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~ao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtata|a~ao|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   'tata|a~ao|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~ao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>ata|a~au|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~ao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nata|a~au|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   'ta|a~ao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(IX) tsulatsy': {'mu|oa~N|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'Ai|oiaAF|A': ['هُوَ', 'مَصْدَرْ'],
#   'ya|oa~u|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oa~a|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   'mu|oa~a|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|oa~a|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ya|oa~a|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   'Ai|aa~a|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|oa~u|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'mu|oa~i|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'ya|oa~u|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oa~u|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'mu|oa~a|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'ta|oa~u|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oa~a|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'mu|oa~a|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|oa~a|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ta|oa~a|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oa~a|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|oa~a|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'ya|oaao|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oaao|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'laAta|oa~a|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   'Ai|oaao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAta|oa~a|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   'Ai|oa~a|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   'Ai|oaao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAta|oa~u|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   'ta|oa~u|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oaao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAta|oa~i|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   'Ai|oa~i|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'ta|oa~i|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oaao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAta|oaao|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   'ta|oaao|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oaao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|oa~u|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oaao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|oa~u|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   'Ai|oaao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  'Iaa': {'ma|ouwoN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ya|oau|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ya|oaa|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwou|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoi|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   '|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'ya|oau|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'ta|oau|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ta|oaa|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'ya|oao|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAta|oao|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '>i|oao|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAta|oaa|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '>i|oaa|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAta|oau|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '>i|oau|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'ta|oau|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAta|oai|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '>i|oai|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'ta|oai|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAta|oao|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '>i|oao|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'ta|oao|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|oau|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|oau|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  'Iai': {'ma|ouwoN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ya|oiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ya|oia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwou|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoi|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   '|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'ya|oiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'ta|oiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ta|oia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'ya|oio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAta|oio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '>i|oio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAta|oia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '>i|oia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAta|oiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '>i|oiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'ta|oiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAta|oii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '>i|oii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'ta|oii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAta|oio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '>i|oio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'ta|oio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|oiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|oiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  'Iia': {'ma|ouwoN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ya|oau|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aia|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ya|oaa|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aia|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwou|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoi|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   '|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'ya|oau|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aiu|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'ta|oau|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aia|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ta|oaa|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aia|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'ya|oao|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAta|oio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '>i|oio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aio|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAta|oia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '>i|oia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aio|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAta|oiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '>i|oiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'ta|oau|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAta|oii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '>i|oii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'ta|oai|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAta|oio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '>i|oio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'ta|oao|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|oau|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aio|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|oau|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aio|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  "(I) ruba'iy": {'mu|aoaN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   '|aoaa|pF': ['هُوَ', 'مَصْدَرْ'],
#   'yu|aoiu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aoaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'mu|aoaa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoaa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|aoia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yu|aoia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aoaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|aoau|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'mu|aoii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yu|aoiu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aoau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'mu|aoaa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tu|aoiu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aoaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'mu|aoaa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoaa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|aoia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tu|aoia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aoaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|aoaa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|aoia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yu|aoio|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aoao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtu|aoio|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '|aoio|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aoao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtu|aoia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '|aoia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aoao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtu|aoiu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '|aoiu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tu|aoiu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aoao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtu|aoii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '|aoii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tu|aoii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aoao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtu|aoio|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '|aoio|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tu|aoio|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aoao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>u|aoiu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aoao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nu|aoiu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aoao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  '(II) tsulatsy': {'mu|a~aN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~iN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ta|oiyoF|': ['هُوَ', 'مَصْدَرْ'],
#   'yu|a~iu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|a~aa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'mu|a~aa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~aa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~ia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|a~ia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'yu|a~ia|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|a~aa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|a~au|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~ai|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~iu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'mu|a~ii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'yu|a~iu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|a~au|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'mu|a~aa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~ia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'tu|a~iu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|a~aa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'mu|a~aa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~aa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~ia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'mu|a~ia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'tu|a~ia|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|a~aa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'mu|a~aa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   'mu|a~ia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'yu|a~io|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|a~ao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAtu|a~io|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '|a~io|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|a~ao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAtu|a~ia|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '|a~ia|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|a~ao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAtu|a~iu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '|a~iu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'tu|a~iu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|a~ao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAtu|a~ii|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '|a~ii|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'tu|a~ii|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|a~ao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAtu|a~io|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '|a~io|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'tu|a~io|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|a~ao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>u|a~iu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|a~ao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'nu|a~iu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|a~ao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']},
#  'Iau': {'ma|ouwoN|': ['هُوَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiN|': ['هُوَ', 'اِسِمْ فَاعِلْ'],
#   'ya|ouu|': ['هُوَ', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|': ['هُوَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|Ani': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|yoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|Ani': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|yoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ya|oua|Ani': ['هُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|A': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwou|wona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoi|yona': ['هُمْ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAiu|wona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   '|aAii|yona': ['هُمْ', 'اِسِمْ فَاعِلْ'],
#   'ya|ouu|wona': ['هُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aau|woA': ['هُمْ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|pN': ['هِيَ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|pN': ['هِيَ', 'اِسِمْ فَاعِلْ'],
#   'ta|ouu|': ['أَنْتَ', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|to': ['هِيَ', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|taAni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   'ma|ouwoa|tayoni': ['هُمَا', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|taAni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   '|aAia|tayoni': ['هُمَا', 'اِسِمْ فَاعِلْ'],
#   'ta|oua|Ani': ['أَنْتُمَا', 'فِعِلْ مُضَارِعْ'],
#   '|aaa|taA': ['هُمَا', 'فِعِلْ مَاضِ'],
#   'ma|ouwoa|AtN': ['هُنَّ', 'اِسِمْ مَفْعُوْلْ'],
#   '|aAia|AtN': ['هُنَّ', 'اِسِمْ فَاعِلْ'],
#   'ya|ouo|na': ['هُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|na': ['هُنَّ', 'فِعِلْ مَاضِ'],
#   'laAta|ouo|': ['أَنْتَ', 'فِعِلْ النَهْيِ'],
#   '>u|ouo|': ['أَنْتَ', 'فِعِلْ الأَمرْ'],
#   '|aao|ta': ['أَنْتَ', 'فِعِلْ مَاضِ'],
#   'laAta|oua|A': ['أَنْتُمَا', 'فِعِلْ النَهْيِ'],
#   '>u|oua|A': ['أَنْتُمَا', 'فِعِلْ الأَمرْ'],
#   '|aao|tumaA': ['أَنْتُمَا', 'فِعِلْ مَاضِ'],
#   'laAta|ouu|woA': ['أَنْتُمْ', 'فِعِلْ النَهْيِ'],
#   '>u|ouu|woA': ['أَنْتُمْ', 'فِعِلْ الأَمرْ'],
#   'ta|ouu|wona': ['أَنْتُمْ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tumo': ['أَنْتُمْ', 'فِعِلْ مَاضِ'],
#   'laAta|oui|yo': ['أَنْتِ', 'فِعِلْ النَهْيِ'],
#   '>u|oui|yo': ['أَنْتِ', 'فِعِلْ الأَمرْ'],
#   'ta|oui|yona': ['أَنْتِ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|ti': ['أَنْتِ', 'فِعِلْ مَاضِ'],
#   'laAta|ouo|na': ['أَنْتُنَّ', 'فِعِلْ النَهْيِ'],
#   '>u|ouo|na': ['أَنْتُنَّ', 'فِعِلْ الأَمرْ'],
#   'ta|ouo|na': ['أَنْتُنَّ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tun~a': ['أَنْتُنَّ', 'فِعِلْ مَاضِ'],
#   '>a|ouu|': ['أَنَا', 'فِعِلْ مُضَارِعْ'],
#   '|aao|tu': ['أَنَا', 'فِعِلْ مَاضِ'],
#   'na|ouu|': ['نَحْنُ', 'فِعِلْ مُضَارِعْ'],
#   '|aao|naA': ['نَحْنُ', 'فِعِلْ مَاضِ']}}

# %%
pattern_berhasil = []
pattern_gagal = []
list_tow = []
list_pron = []
for i in range(0,len(X_data)):
    pattern = X_data[i]['string_pattern']
    wazan = X_data[i]['wazan']
    wazan_predict =  X_data[i]['wazan_predict']
    word = X_data[i]['word']
    if 'w' in X_data[i]['pattern']['suffix'] and 'o' not in X_data[i]['pattern']['suffix']:
        if len(X_data[i]['pattern']['suffix']) == 1:
            suffix = 'woA'
        else:
            pos = X_data[i]['pattern']['suffix'].find('w')+1
            suffix = X_data[i]['pattern']['suffix'][:pos] + 'o' + X_data[i]['pattern']['suffix'][pos:]
        if(suffix != 'wona' and X_data[i]['pattern']['prefix'] != 'laAta' and X_data[i]['pattern']['prefix'] != '>u' and X_data[i]['pattern']['prefix'] != '' and X_data[i]['pattern']['prefix'] != '>i'):
            suffix = 'wona'
        pattern =  X_data[i]['pattern']['prefix']+'|'+''.join( X_data[i]['pattern']['infix'])+'|'+suffix
    if (pattern in dict_wazan_pattern[wazan_predict]):
        result = dict_wazan_pattern[wazan_predict][pattern]
        X_data[i]['tow'] = result[1]
        X_data[i]['pron'] = result[0]
        list_tow.append(result[1])
        list_pron.append(result[0])
        pattern_berhasil.append([word,pattern,wazan,wazan_predict])
    else:
        pattern_gagal.append([word,pattern,wazan,wazan_predict])

# %%
len(pattern_berhasil)
# Out:
# 6133

# %%
len(pattern_gagal)
# Out:
# 55

# %%
pattern_gagal
# Out:
# [['>a$oxaSu', '>a|oau|', 'Iaa', '(IV) tsulatsy'],
#  ['>usojunaA', '|ou|', 'Iau', 'Iau'],
#  ['>aTomivu', '>a|oiu|', 'Iai', 'Iia'],
#  ['>uqonutaA', '|ou|', 'Iau', 'Iau'],
#  ['laAtanoTaliquwoA', 'laAta|oaiu|woA', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['laAtanoqalibaA', 'laAta|oaia|A', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['>arojiEu', '>a|oiu|', 'Iai', '(IV) tsulatsy'],
#  ['Aino$aqaqoti', 'Aino|aao|ti', '(IX) tsulatsy', '(IX) tsulatsy'],
#  ['laAtu*oEinaA', '|aAuoi|naA', '(IV) tsulatsy', '(IV) tsulatsy'],
#  ['>aboxalu', '>a|oau|', 'Iia', '(IV) tsulatsy'],
#  ['laAtanotaZiruwoA', 'laAta|oaiu|woA', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['>aEolinaA', '|oi|', '(IV) tsulatsy', '(IV) tsulatsy'],
#  ['laAtarokinaA', '|aAaoi|naA', 'Iia', 'Iia'],
#  ['taqonutu', '|aou|tu', 'Iau', 'Iau'],
#  ['laAtudohinaA', '|aAuoi|naA', '(IV) tsulatsy', '(IV) tsulatsy'],
#  ['laAtakotumaA', '|aAao|tumaA', 'Iau', 'Iau'],
#  ['>asokana', '|oa|', '(IV) tsulatsy', '(IV) tsulatsy'],
#  ['laAtanota$irona', 'laAta|oaio|na', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['haAjiraA', '|aAia|A', '(III) tsulatsy', 'Iau'],
#  ['>unoHutaA', '|ou|', 'Iau', 'Iau'],
#  ['laAtanofakakona', 'laAta|oaao|na', '(IX) tsulatsy', 'Iai'],
#  ['laAtaToEanaA', '|aAaoa|naA', 'Iaa', 'Iaa'],
#  ['taEoruDiyona', 'ta|oui|yona', 'Iuu', '(VI) tsulatsy'],
#  ['maqonuwotayoni', '|aouwo|tayoni', 'Iau', 'Iau'],
#  ['nanoHutu', '|aou|tu', 'Iau', 'Iau'],
#  ['Ainofakakona', 'Aino|aao|na', '(IX) tsulatsy', '(IX) tsulatsy'],
#  ['laAtanotaZirona', 'laAta|oaio|na', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['laAtanotaqimuwoA', 'laAta|oaiu|woA', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['SaAHibiyona', '|aAii|yona', 'Iia', '(III) tsulatsy'],
#  ['yasobutu', '|ou|', 'Iau', 'Iau'],
#  ['takobitaAni', '|aoi|taAni', 'Iai', 'Iai'],
#  ['makobuwotayoni', '|aouwo|tayoni', 'Iai', 'Iai'],
#  ['laAtakobitaA', '|aAaoi|taA', 'Iai', 'Iai'],
#  ['>imohadaA', '>i|oaa|A', 'Iaa', 'Iia'],
#  ['tanofakakona', 'tano|aao|na', '(IX) tsulatsy', '(IX) tsulatsy'],
#  ['tavobutu', '|aou|tu', 'Iau', 'Iau'],
#  ['>aqosimu', '>a|oiu|', 'Iai', '(IV) tsulatsy'],
#  ['>usobuto', '|ou|', 'Iau', 'Iau'],
#  ['laAtuxobito', '|aAuoi|to', '(IV) tsulatsy', '(IV) tsulatsy'],
#  ['>anoTaliqu', '>ano|aiu|', '(VII) tsulatsy', '(X) tsulatsy'],
#  ['>aHokamataA', '>a|oaa|taA', '(IV) tsulatsy', '(X) tsulatsy'],
#  ['laAtanoTaliqona', 'laAta|oaio|na', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['Ainofakakotun~a', 'Aino|aao|tun~a', '(IX) tsulatsy', '(IX) tsulatsy'],
#  ['laAtanotaqimiyo', 'laAta|oaii|yo', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['tanoEiyomF', 'tano|iyoF|', '(II) tsulatsy', '(II) tsulatsy'],
#  ['laAtanoTaliqiyo', 'laAta|oaii|yo', '(VII) tsulatsy', '(VII) tsulatsy'],
#  ['laAtuqorinaA', '|aAuoi|naA', '(IV) tsulatsy', '(IV) tsulatsy'],
#  ['haAjiriyo', '|aAii|yo', '(III) tsulatsy', 'Iau'],
#  ['navobutu', '|aou|tu', 'Iau', 'Iau'],
#  ['>asomaEu', '>a|oau|', 'Iia', '(IV) tsulatsy'],
#  ['>anoHutu', '|ou|', 'Iau', 'Iau'],
#  ['yuvab~itu', '|a~i|', '(II) tsulatsy', '(II) tsulatsy'],
#  ['>iloEanaA', '|oa|', 'Iaa', 'Iaa'],
#  ['yaqonutu', '|ou|', 'Iau', 'Iau'],
#  ['>anota$iru', '>ano|aiu|', '(VII) tsulatsy', 'Iia']]

# %%
len(pattern_berhasil)/len(X_data)
# Out:
# 0.9911118293471235

# %% [markdown]
# # MSD Identification

# %%
list_tow = list(set(list_tow))
list_pron = list(set(list_pron))

# %%
list_tow
# Out:
# ['فِعِلْ مَاضِ',
#  'اِسِمْ مَفْعُوْلْ',
#  'فِعِلْ النَهْيِ',
#  'اِسِمْ فَاعِلْ',
#  'فِعِلْ الأَمرْ',
#  'مَصْدَرْ',
#  'فِعِلْ مُضَارِعْ']

# %%
list_pron
# Out:
# ['هُمْ',
#  'أَنْتُنَّ',
#  'نَحْنُ',
#  'هُمَا',
#  'أَنْتِ',
#  'هِيَ',
#  'هُوَ',
#  'هُنَّ',
#  'أَنْتَ',
#  'أَنَا',
#  'أَنْتُمْ',
#  'أَنْتُمَا']

# %%
dict_msd = {
    'اِسِمْ فَاعِلْ':{'POS':'N'},
    'اِسِمْ مَفْعُوْلْ':{'POS':'N'},
    'فِعِلْ مَاضِ':{'POS':'V','aspect':'PFV','tense':'PST'},
    'فِعِلْ مُضَارِعْ':{'POS':'V','aspect':'IPFV','tense':'PRS/FUT'},
    'فِعِلْ الأَمرْ':{'POS':'V','mood':'IMP'},
    'فِعِلْ النَهْيِ':{'POS':'V','mood':'IMP'},
    'مَصْدَرْ':{'POS':'N'},
    'أَنْتُنَّ':{'PER':'2','NUM':'PL','GEN':'FEM'},
    'هِيَ':{'PER':'3','NUM':'SG','GEN':'FEM'},
    'أَنَا':{'PER':'1','NUM':'SG'},
    'نَحْنُ':{'PER':'1','NUM':'PL'},
    'هُمْ':{'PER':'3','NUM':'PL','GEN':'MASC'},
    'هُنَّ':{'PER':'3','NUM':'PL','GEN':'FEM'},
    'أَنْتَ':{'PER':'2','NUM':'SG','GEN':'MASC'},
    'هُوَ':{'PER':'3','NUM':'SG','GEN':'MASC'},
    'أَنْتُمْ':{'PER':'2','NUM':'PL','GEN':'MASC'},
    'هُمَا':{'PER':'3','NUM':'DU'},
    'أَنْتُمَا':{'PER':'2','NUM':'DU'},
    'أَنْتِ':{'PER':'2','NUM':'SG','GEN':'FEM'}
}

# %%
dataGagal = []

for i in range(0,len(X_data)):
    verbForm = {'Verb Form':X_data[i]['wazan_predict']}
    if ('tow' in X_data[i] ):
        tow = X_data[i]['tow']
        pron = X_data[i]['pron']
        dict_tow = dict_msd[tow].copy() 
        dict_pron = dict_msd[pron].copy() 
        dict_tow.update(dict_pron)
        dict_tow.update(verbForm)
        if (dict_tow['POS'] == 'N'):
            del dict_tow['PER']
        X_data[i]['msd'] = dict_tow
    else:
        X_data[i]['msd_predict'] = verbForm
        dataGagal.append(X_data[i])
    if (X_data[i]['wazan_predict'] != X_data[i]['wazan']):
        dataGagal.append(X_data[i])

# %%
import json

dataGabung = []
for x in X_data:
    if 'tow' in x:
        dataGabung.append([buckwalter.untransliterate(x['word']),json.dumps(x['msd']),x['tow'],x['pron'],x['wazan'],x['wazan_predict']])
    else:
        dataGabung.append([buckwalter.untransliterate(x['word']),json.dumps(x['msd']),'','',x['wazan'],x['wazan_predict']])
# Out:
# {'word': 'narokaEu', 'pattern': {'prefix': 'na', 'infix': ['o', 'a', 'u'], 'suffix': '', 'root': ['r', 'k', 'E']}, 'string_pattern': 'na|oau|', 'vector': array([31., 10.,  7., 22., 14., 18., 12.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'نَحْنُ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '1', 'NUM': 'PL', 'Verb Form': 'Iaa'}}
# {'word': '>iSodaEo', 'pattern': {'prefix': '>i', 'infix': ['o', 'a', 'o'], 'suffix': '', 'root': ['S', 'd', 'E']}, 'string_pattern': '>i|oao|', 'vector': array([26., 14.,  7.,  8., 14., 18., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': 'Iaa'}}
# {'word': 'manaEotumaA', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'o'], 'suffix': 'tumaA', 'root': ['m', 'n', 'E']}, 'string_pattern': '|aao|tumaA', 'vector': array([ 1., 24.,  5., 25., 14., 18., 11.,  1.,  1.,  1.,  1.,  4.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '2', 'NUM': 'DU', 'Verb Form': 'Iaa'}}
# {'word': 'mat~iEiyo', 'pattern': {'prefix': '', 'infix': ['a', '~i', 'i'], 'suffix': 'yo', 'root': ['m', 't', 'E']}, 'string_pattern': '|a~ii|yo', 'vector': array([ 1., 24.,  5.,  3., 12., 18., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'ma$okuworuwona', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'u'], 'suffix': 'wona', 'root': ['$', 'k', 'r']}, 'string_pattern': 'ma|ouwou|wona', 'vector': array([29., 13.,  7., 22.,  9., 10., 12.,  1.,  1.,  1.,  1.,  9.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iau'}}
# {'word': 'murotad~atayoni', 'pattern': {'prefix': 'mu', 'infix': ['o', 'a', '~a'], 'suffix': 'tayoni', 'root': ['r', 't', 'd']}, 'string_pattern': 'mu|oa~a|tayoni', 'vector': array([30., 10.,  7.,  3., 14.,  8.,  4.,  1.,  1.,  1.,  1.,  2.]), 'wazan': '(IX) tsulatsy', 'wazan_predict': '(IX) tsulatsy', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': '(IX) tsulatsy'}}
# {'word': 'maqotuwolaAni', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'a'], 'suffix': 'Ani', 'root': ['q', 't', 'l']}, 'string_pattern': 'ma|ouwoa|Ani', 'vector': array([29., 21.,  7.,  3.,  9., 23.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iau'}}
# {'word': 'HaAfiZaA', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'A', 'root': ['H', 'f', 'Z']}, 'string_pattern': '|aAia|A', 'vector': array([ 1.,  6.,  4., 20., 15., 17.,  9.,  1.,  1.,  1.,  1., 34.]), 'wazan': '(III) tsulatsy', 'wazan_predict': '(III) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'DU', 'Verb Form': '(III) tsulatsy'}}
# {'word': 'Eaz~iro', 'pattern': {'prefix': '', 'infix': ['a', '~i', 'o'], 'suffix': '', 'root': ['E', 'z', 'r']}, 'string_pattern': '|a~io|', 'vector': array([ 1., 18.,  5., 11., 12., 10., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'HaAribiyo', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'i'], 'suffix': 'yo', 'root': ['H', 'r', 'b']}, 'string_pattern': '|aAii|yo', 'vector': array([ 1.,  6.,  4., 10., 15.,  2., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': '(III) tsulatsy', 'wazan_predict': '(III) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(III) tsulatsy'}}
# {'word': 'yanotaqimaAni', 'pattern': {'prefix': 'yano', 'infix': ['a', 'i', 'a'], 'suffix': 'Ani', 'root': ['t', 'q', 'm']}, 'string_pattern': 'yano|aia|Ani', 'vector': array([23.,  3.,  5., 21., 15., 24.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': '(VII) tsulatsy', 'wazan_predict': '(VII) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'DU', 'Verb Form': '(VII) tsulatsy'}}
# {'word': 'mu*ab~aHapN', 'pattern': {'prefix': 'mu', 'infix': ['a', '~a', 'a'], 'suffix': 'pN', 'root': ['*', 'b', 'H']}, 'string_pattern': 'mu|a~aa|pN', 'vector': array([30.,  9.,  5.,  2., 11.,  6.,  9.,  1.,  1.,  1.,  1., 28.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هِيَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'basarotumaA', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'o'], 'suffix': 'tumaA', 'root': ['b', 's', 'r']}, 'string_pattern': '|aao|tumaA', 'vector': array([ 1.,  2.,  5., 12., 14., 10., 11.,  1.,  1.,  1.,  1.,  4.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '2', 'NUM': 'DU', 'Verb Form': 'Iau'}}
# {'word': 'maqohuworaAtN', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'a'], 'suffix': 'AtN', 'root': ['q', 'h', 'r']}, 'string_pattern': 'ma|ouwoa|AtN', 'vector': array([29., 21.,  7., 26.,  9., 10.,  9.,  1.,  1.,  1.,  1., 15.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُنَّ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iaa'}}
# {'word': 'musotaxorijatayoni', 'pattern': {'prefix': 'musota', 'infix': ['o', 'i', 'a'], 'suffix': 'tayoni', 'root': ['x', 'r', 'j']}, 'string_pattern': 'musota|oia|tayoni', 'vector': array([ 8.,  7.,  7., 10., 15.,  5.,  9.,  1.,  1.,  1.,  1.,  2.]), 'wazan': '(X) tsulatsy', 'wazan_predict': '(X) tsulatsy', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': '(X) tsulatsy'}}
# {'word': '>a$ofiqaA', 'pattern': {'prefix': '>a', 'infix': ['o', 'i', 'a'], 'suffix': 'A', 'root': ['$', 'f', 'q']}, 'string_pattern': '>a|oia|A', 'vector': array([25., 13.,  7., 20., 15., 21.,  9.,  1.,  1.,  1.,  1., 34.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'DU', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'muEojibatayoni', 'pattern': {'prefix': 'mu', 'infix': ['o', 'i', 'a'], 'suffix': 'tayoni', 'root': ['E', 'j', 'b']}, 'string_pattern': 'mu|oia|tayoni', 'vector': array([30., 18.,  7.,  5., 15.,  2.,  9.,  1.,  1.,  1.,  1.,  2.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'yaEoDulaAni', 'pattern': {'prefix': 'ya', 'infix': ['o', 'u', 'a'], 'suffix': 'Ani', 'root': ['E', 'D', 'l']}, 'string_pattern': 'ya|oua|Ani', 'vector': array([35., 18.,  7., 15., 17., 23.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'DU', 'Verb Form': 'Iau'}}
# {'word': 'SadaEotun~a', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'o'], 'suffix': 'tun~a', 'root': ['S', 'd', 'E']}, 'string_pattern': '|aao|tun~a', 'vector': array([ 1., 14.,  5.,  8., 14., 18., 11.,  1.,  1.,  1.,  1.,  3.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iaa'}}
# {'word': 'yaEolamona', 'pattern': {'prefix': 'ya', 'infix': ['o', 'a', 'o'], 'suffix': 'na', 'root': ['E', 'l', 'm']}, 'string_pattern': 'ya|oao|na', 'vector': array([35., 18.,  7., 23., 14., 24., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُنَّ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iia'}}
# {'word': 'takab~arotu', 'pattern': {'prefix': 'ta', 'infix': ['a', '~a', 'o'], 'suffix': 'tu', 'root': ['k', 'b', 'r']}, 'string_pattern': 'ta|a~ao|tu', 'vector': array([33., 22.,  5.,  2., 11., 10., 11.,  1.,  1.,  1.,  1., 24.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '1', 'NUM': 'SG', 'Verb Form': '(V) tsulatsy'}}
# {'word': 'munoTaqaAtN', 'pattern': {'prefix': 'mu', 'infix': ['o', 'a', 'a'], 'suffix': 'AtN', 'root': ['n', 'T', 'q']}, 'string_pattern': 'mu|oaa|AtN', 'vector': array([30., 25.,  7., 16., 14., 21.,  9.,  1.,  1.,  1.,  1., 15.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُنَّ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'nusax~iru', 'pattern': {'prefix': 'nu', 'infix': ['a', '~i', 'u'], 'suffix': '', 'root': ['s', 'x', 'r']}, 'string_pattern': 'nu|a~iu|', 'vector': array([32., 12.,  5.,  7., 12., 10., 12.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'نَحْنُ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '1', 'NUM': 'PL', 'Verb Form': '(II) tsulatsy'}}
# {'word': '>iEoqaAbFA', 'pattern': {'prefix': '>i', 'infix': ['o', 'aA', 'F'], 'suffix': 'A', 'root': ['E', 'q', 'b']}, 'string_pattern': '>i|oaAF|A', 'vector': array([26., 18.,  7., 21., 10.,  2.,  7.,  1.,  1.,  1.,  1., 34.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'مَصْدَرْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'SaAbirapN', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'pN', 'root': ['S', 'b', 'r']}, 'string_pattern': '|aAia|pN', 'vector': array([ 1., 14.,  4.,  2., 15., 10.,  9.,  1.,  1.,  1.,  1., 28.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هِيَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': 'Iai'}}
# {'word': 'HaADiraAni', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'Ani', 'root': ['H', 'D', 'r']}, 'string_pattern': '|aAia|Ani', 'vector': array([ 1.,  6.,  4., 15., 15., 10.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iau'}}
# {'word': 'EarajuwoA', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'u'], 'suffix': 'woA', 'root': ['E', 'r', 'j']}, 'string_pattern': '|aau|woA', 'vector': array([ 1., 18.,  5., 10., 14.,  5., 12.,  1.,  1.,  1.,  1., 11.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مَاضِ', 'pron': 'هُمْ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '3', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iau'}}
# {'word': '>adoxilo', 'pattern': {'prefix': '>a', 'infix': ['o', 'i', 'o'], 'suffix': '', 'root': ['d', 'x', 'l']}, 'string_pattern': '>a|oio|', 'vector': array([25.,  8.,  7.,  7., 15., 23., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'tarab~aSona', 'pattern': {'prefix': 'ta', 'infix': ['a', '~a', 'o'], 'suffix': 'na', 'root': ['r', 'b', 'S']}, 'string_pattern': 'ta|a~ao|na', 'vector': array([33., 10.,  5.,  2., 11., 14., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(V) tsulatsy'}}
# {'word': 'AisotiEotaAbFA', 'pattern': {'prefix': 'Aisoti', 'infix': ['o', 'aA', 'F'], 'suffix': 'A', 'root': ['E', 't', 'b']}, 'string_pattern': 'Aisoti|oaAF|A', 'vector': array([ 7., 18.,  7.,  3., 10.,  2.,  7.,  1.,  1.,  1.,  1., 34.]), 'wazan': '(X) tsulatsy', 'wazan_predict': '(X) tsulatsy', 'tow': 'مَصْدَرْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(X) tsulatsy'}}
# {'word': 'Sar~afota', 'pattern': {'prefix': '', 'infix': ['a', '~a', 'o'], 'suffix': 'ta', 'root': ['S', 'r', 'f']}, 'string_pattern': '|a~ao|ta', 'vector': array([ 1., 14.,  5., 10., 11., 20., 11.,  1.,  1.,  1.,  1., 27.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'tu$oriqaAni', 'pattern': {'prefix': 'tu', 'infix': ['o', 'i', 'a'], 'suffix': 'Ani', 'root': ['$', 'r', 'q']}, 'string_pattern': 'tu|oia|Ani', 'vector': array([34., 13.,  7., 10., 15., 21.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'DU', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'salabuwoA', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'u'], 'suffix': 'woA', 'root': ['s', 'l', 'b']}, 'string_pattern': '|aau|woA', 'vector': array([ 1., 12.,  5., 23., 14.,  2., 12.,  1.,  1.,  1.,  1., 11.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مَاضِ', 'pron': 'هُمْ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '3', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iau'}}
# {'word': 'EaAqiraAtN', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'AtN', 'root': ['E', 'q', 'r']}, 'string_pattern': '|aAia|AtN', 'vector': array([ 1., 18.,  4., 21., 15., 10.,  9.,  1.,  1.,  1.,  1., 15.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُنَّ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iai'}}
# {'word': '>ilofaHo', 'pattern': {'prefix': '>i', 'infix': ['o', 'a', 'o'], 'suffix': '', 'root': ['l', 'f', 'H']}, 'string_pattern': '>i|oao|', 'vector': array([26., 23.,  7., 20., 14.,  6., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': 'Iaa'}}
# {'word': 'mutaSad~aqN', 'pattern': {'prefix': 'muta', 'infix': ['a', '~a', 'N'], 'suffix': '', 'root': ['S', 'd', 'q']}, 'string_pattern': 'muta|a~aN|', 'vector': array([18., 14.,  5.,  8., 11., 21.,  8.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(V) tsulatsy'}}
# {'word': '>unofiqu', 'pattern': {'prefix': '>u', 'infix': ['o', 'i', 'u'], 'suffix': '', 'root': ['n', 'f', 'q']}, 'string_pattern': '>u|oiu|', 'vector': array([27., 25.,  7., 20., 15., 21., 12.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '1', 'NUM': 'SG', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'saAbitayoni', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'yoni', 'root': ['s', 'b', 't']}, 'string_pattern': '|aAia|yoni', 'vector': array([ 1., 12.,  4.,  2., 15.,  3.,  9.,  1.,  1.,  1.,  1.,  7.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iau'}}
# {'word': '>aEotido', 'pattern': {'prefix': '>a', 'infix': ['o', 'i', 'o'], 'suffix': '', 'root': ['E', 't', 'd']}, 'string_pattern': '>a|oio|', 'vector': array([25., 18.,  7.,  3., 15.,  8., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'laAtatolifuwoA', 'pattern': {'prefix': 'laAta', 'infix': ['o', 'i', 'u'], 'suffix': 'woA', 'root': ['t', 'l', 'f']}, 'string_pattern': 'laAta|oiu|woA', 'vector': array([12.,  3.,  7., 23., 15., 20., 12.,  1.,  1.,  1.,  1., 11.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتُمْ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iai'}}
# {'word': 'laAtusolifo', 'pattern': {'prefix': 'laAtu', 'infix': ['o', 'i', 'o'], 'suffix': '', 'root': ['s', 'l', 'f']}, 'string_pattern': 'laAtu|oio|', 'vector': array([13., 12.,  7., 23., 15., 20., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'tarozuqona', 'pattern': {'prefix': 'ta', 'infix': ['o', 'u', 'o'], 'suffix': 'na', 'root': ['r', 'z', 'q']}, 'string_pattern': 'ta|ouo|na', 'vector': array([33., 10.,  7., 11., 17., 21., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iau'}}
# {'word': 'marohuwobiyona', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'i'], 'suffix': 'yona', 'root': ['r', 'h', 'b']}, 'string_pattern': 'ma|ouwoi|yona', 'vector': array([29., 10.,  7., 26.,  9.,  2., 10.,  1.,  1.,  1.,  1.,  8.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iia'}}
# {'word': 'laAtufan~idiyo', 'pattern': {'prefix': 'laAtu', 'infix': ['a', '~i', 'i'], 'suffix': 'yo', 'root': ['f', 'n', 'd']}, 'string_pattern': 'laAtu|a~ii|yo', 'vector': array([13., 20.,  5., 25., 12.,  8., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'faS~alona', 'pattern': {'prefix': '', 'infix': ['a', '~a', 'o'], 'suffix': 'na', 'root': ['f', 'S', 'l']}, 'string_pattern': '|a~ao|na', 'vector': array([ 1., 20.,  5., 14., 11., 23., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'هُنَّ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '3', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'maTomuwosayoni', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'a'], 'suffix': 'yoni', 'root': ['T', 'm', 's']}, 'string_pattern': 'ma|ouwoa|yoni', 'vector': array([29., 16.,  7., 24.,  9., 12.,  9.,  1.,  1.,  1.,  1.,  7.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iai'}}
# {'word': 'nasafato', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'a'], 'suffix': 'to', 'root': ['n', 's', 'f']}, 'string_pattern': '|aaa|to', 'vector': array([ 1., 25.,  5., 12., 14., 20.,  9.,  1.,  1.,  1.,  1., 25.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'فِعِلْ مَاضِ', 'pron': 'هِيَ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '3', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': 'Iai'}}
# {'word': '>iHosibiyo', 'pattern': {'prefix': '>i', 'infix': ['o', 'i', 'i'], 'suffix': 'yo', 'root': ['H', 's', 'b']}, 'string_pattern': '>i|oii|yo', 'vector': array([26.,  6.,  7., 12., 15.,  2., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': 'Iii', 'wazan_predict': 'Iii', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': 'Iii'}}
# {'word': 'naba*ataA', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'a'], 'suffix': 'taA', 'root': ['n', 'b', '*']}, 'string_pattern': '|aaa|taA', 'vector': array([ 1., 25.,  5.,  2., 14.,  9.,  9.,  1.,  1.,  1.,  1., 12.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'فِعِلْ مَاضِ', 'pron': 'هُمَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '3', 'NUM': 'DU', 'Verb Form': 'Iai'}}
# {'word': 'mafoquwodayoni', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'a'], 'suffix': 'yoni', 'root': ['f', 'q', 'd']}, 'string_pattern': 'ma|ouwoa|yoni', 'vector': array([29., 20.,  7., 21.,  9.,  8.,  9.,  1.,  1.,  1.,  1.,  7.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iai'}}
# {'word': 'tukal~ibiyona', 'pattern': {'prefix': 'tu', 'infix': ['a', '~i', 'i'], 'suffix': 'yona', 'root': ['k', 'l', 'b']}, 'string_pattern': 'tu|a~ii|yona', 'vector': array([34., 22.,  5., 23., 12.,  2., 10.,  1.,  1.,  1.,  1.,  8.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'munaz~alapN', 'pattern': {'prefix': 'mu', 'infix': ['a', '~a', 'a'], 'suffix': 'pN', 'root': ['n', 'z', 'l']}, 'string_pattern': 'mu|a~aa|pN', 'vector': array([30., 25.,  5., 11., 11., 23.,  9.,  1.,  1.,  1.,  1., 28.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هِيَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'maSoduwoEiyona', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'i'], 'suffix': 'yona', 'root': ['S', 'd', 'E']}, 'string_pattern': 'ma|ouwoi|yona', 'vector': array([29., 14.,  7.,  8.,  9., 18., 10.,  1.,  1.,  1.,  1.,  8.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iaa'}}
# {'word': 'majonuwobiyona', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'i'], 'suffix': 'yona', 'root': ['j', 'n', 'b']}, 'string_pattern': 'ma|ouwoi|yona', 'vector': array([29.,  5.,  7., 25.,  9.,  2., 10.,  1.,  1.,  1.,  1.,  8.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iau'}}
# {'word': 'kaAsibaAtN', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'AtN', 'root': ['k', 's', 'b']}, 'string_pattern': '|aAia|AtN', 'vector': array([ 1., 22.,  4., 12., 15.,  2.,  9.,  1.,  1.,  1.,  1., 15.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُنَّ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iai'}}
# {'word': 'yaEomahaAni', 'pattern': {'prefix': 'ya', 'infix': ['o', 'a', 'a'], 'suffix': 'Ani', 'root': ['E', 'm', 'h']}, 'string_pattern': 'ya|oaa|Ani', 'vector': array([35., 18.,  7., 24., 14., 26.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'DU', 'Verb Form': 'Iaa'}}
# {'word': 'tuHad~ivaAni', 'pattern': {'prefix': 'tu', 'infix': ['a', '~i', 'a'], 'suffix': 'Ani', 'root': ['H', 'd', 'v']}, 'string_pattern': 'tu|a~ia|Ani', 'vector': array([34.,  6.,  5.,  8., 12.,  4.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'DU', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'tanoTiqaAni', 'pattern': {'prefix': 'ta', 'infix': ['o', 'i', 'a'], 'suffix': 'Ani', 'root': ['n', 'T', 'q']}, 'string_pattern': 'ta|oia|Ani', 'vector': array([33., 25.,  7., 16., 15., 21.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'DU', 'Verb Form': 'Iai'}}
# {'word': 'mutabat~alaAtN', 'pattern': {'prefix': 'muta', 'infix': ['a', '~a', 'a'], 'suffix': 'AtN', 'root': ['b', 't', 'l']}, 'string_pattern': 'muta|a~aa|AtN', 'vector': array([18.,  2.,  5.,  3., 11., 23.,  9.,  1.,  1.,  1.,  1., 15.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُنَّ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(V) tsulatsy'}}
# {'word': 'baATirN', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'N'], 'suffix': '', 'root': ['b', 'T', 'r']}, 'string_pattern': '|aAiN|', 'vector': array([ 1.,  2.,  4., 16., 15., 10.,  8.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': 'Iia'}}
# {'word': 'laAbisaAni', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'a'], 'suffix': 'Ani', 'root': ['l', 'b', 's']}, 'string_pattern': '|aAia|Ani', 'vector': array([ 1., 23.,  4.,  2., 15., 12.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iai'}}
# {'word': '>axolafotu', 'pattern': {'prefix': '>a', 'infix': ['o', 'a', 'o'], 'suffix': 'tu', 'root': ['x', 'l', 'f']}, 'string_pattern': '>a|oao|tu', 'vector': array([25.,  7.,  7., 23., 14., 20., 11.,  1.,  1.,  1.,  1., 24.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '1', 'NUM': 'SG', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'yamohadona', 'pattern': {'prefix': 'ya', 'infix': ['o', 'a', 'o'], 'suffix': 'na', 'root': ['m', 'h', 'd']}, 'string_pattern': 'ya|oao|na', 'vector': array([35., 24.,  7., 26., 14.,  8., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُنَّ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iaa'}}
# {'word': 'musotasoxaraAtN', 'pattern': {'prefix': 'musota', 'infix': ['o', 'a', 'a'], 'suffix': 'AtN', 'root': ['s', 'x', 'r']}, 'string_pattern': 'musota|oaa|AtN', 'vector': array([ 8., 12.,  7.,  7., 14., 10.,  9.,  1.,  1.,  1.,  1., 15.]), 'wazan': '(X) tsulatsy', 'wazan_predict': '(X) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُنَّ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(X) tsulatsy'}}
# {'word': 'tatanaz~alaAni', 'pattern': {'prefix': 'tata', 'infix': ['a', '~a', 'a'], 'suffix': 'Ani', 'root': ['n', 'z', 'l']}, 'string_pattern': 'tata|a~aa|Ani', 'vector': array([22., 25.,  5., 11., 11., 23.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'DU', 'Verb Form': '(V) tsulatsy'}}
# {'word': 'laAtasotasolimo', 'pattern': {'prefix': 'laAtasota', 'infix': ['o', 'i', 'o'], 'suffix': '', 'root': ['s', 'l', 'm']}, 'string_pattern': 'laAtasota|oio|', 'vector': array([ 2., 12.,  7., 23., 15., 24., 11.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(X) tsulatsy', 'wazan_predict': '(X) tsulatsy', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتَ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(X) tsulatsy'}}
# {'word': 'naASiHN', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'N'], 'suffix': '', 'root': ['n', 'S', 'H']}, 'string_pattern': '|aAiN|', 'vector': array([ 1., 25.,  4., 14., 15.,  6.,  8.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iaa', 'wazan_predict': 'Iaa', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': 'Iaa'}}
# {'word': '>unofuxaA', 'pattern': {'prefix': '>u', 'infix': ['o', 'u', 'a'], 'suffix': 'A', 'root': ['n', 'f', 'x']}, 'string_pattern': '>u|oua|A', 'vector': array([27., 25.,  7., 20., 17.,  7.,  9.,  1.,  1.,  1.,  1., 34.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'DU', 'Verb Form': 'Iau'}}
# {'word': 'Eal~amotumaA', 'pattern': {'prefix': '', 'infix': ['a', '~a', 'o'], 'suffix': 'tumaA', 'root': ['E', 'l', 'm']}, 'string_pattern': '|a~ao|tumaA', 'vector': array([ 1., 18.,  5., 23., 11., 24., 11.,  1.,  1.,  1.,  1.,  4.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنْتُمَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '2', 'NUM': 'DU', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'yataHaAkamaAni', 'pattern': {'prefix': 'yata', 'infix': ['aA', 'a', 'a'], 'suffix': 'Ani', 'root': ['H', 'k', 'm']}, 'string_pattern': 'yata|aAaa|Ani', 'vector': array([24.,  6.,  4., 22., 14., 24.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': '(VI) tsulatsy', 'wazan_predict': '(VI) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'DU', 'Verb Form': '(VI) tsulatsy'}}
# {'word': 'musotaqodamuwona', 'pattern': {'prefix': 'musota', 'infix': ['o', 'a', 'u'], 'suffix': 'wona', 'root': ['q', 'd', 'm']}, 'string_pattern': 'musota|oau|wona', 'vector': array([ 8., 21.,  7.,  8., 14., 24., 12.,  1.,  1.,  1.,  1.,  9.]), 'wazan': '(X) tsulatsy', 'wazan_predict': '(X) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': '(X) tsulatsy'}}
# {'word': 'tata*ak~arona', 'pattern': {'prefix': 'tata', 'infix': ['a', '~a', 'o'], 'suffix': 'na', 'root': ['*', 'k', 'r']}, 'string_pattern': 'tata|a~ao|na', 'vector': array([22.,  9.,  5., 22., 11., 10., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(V) tsulatsy'}}
# {'word': 'tukal~ifona', 'pattern': {'prefix': 'tu', 'infix': ['a', '~i', 'o'], 'suffix': 'na', 'root': ['k', 'l', 'f']}, 'string_pattern': 'tu|a~io|na', 'vector': array([34., 22.,  5., 23., 12., 20., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'yaboTaraAni', 'pattern': {'prefix': 'ya', 'infix': ['o', 'a', 'a'], 'suffix': 'Ani', 'root': ['b', 'T', 'r']}, 'string_pattern': 'ya|oaa|Ani', 'vector': array([35.,  2.,  7., 16., 14., 10.,  9.,  1.,  1.,  1.,  1., 16.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'هُمَا', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '3', 'NUM': 'DU', 'Verb Form': 'Iia'}}
# {'word': 'muEa*~irapN', 'pattern': {'prefix': 'mu', 'infix': ['a', '~i', 'a'], 'suffix': 'pN', 'root': ['E', '*', 'r']}, 'string_pattern': 'mu|a~ia|pN', 'vector': array([30., 18.,  5.,  9., 12., 10.,  9.,  1.,  1.,  1.,  1., 28.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هِيَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'qaS~iriyo', 'pattern': {'prefix': '', 'infix': ['a', '~i', 'i'], 'suffix': 'yo', 'root': ['q', 'S', 'r']}, 'string_pattern': '|a~ii|yo', 'vector': array([ 1., 21.,  5., 14., 12., 10., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'laAtamokuriyo', 'pattern': {'prefix': 'laAta', 'infix': ['o', 'u', 'i'], 'suffix': 'yo', 'root': ['m', 'k', 'r']}, 'string_pattern': 'laAta|oui|yo', 'vector': array([12., 24.,  7., 22., 17., 10., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': 'Iau'}}
# {'word': '>uboTuliyo', 'pattern': {'prefix': '>u', 'infix': ['o', 'u', 'i'], 'suffix': 'yo', 'root': ['b', 'T', 'l']}, 'string_pattern': '>u|oui|yo', 'vector': array([27.,  2.,  7., 16., 17., 23., 10.,  1.,  1.,  1.,  1., 23.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتِ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'SG', 'GEN': 'FEM', 'Verb Form': 'Iau'}}
# {'word': 'laAtuno*irona', 'pattern': {'prefix': 'laAtu', 'infix': ['o', 'i', 'o'], 'suffix': 'na', 'root': ['n', '*', 'r']}, 'string_pattern': 'laAtu|oio|na', 'vector': array([13., 25.,  7.,  9., 15., 10., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'tarodafona', 'pattern': {'prefix': 'ta', 'infix': ['o', 'a', 'o'], 'suffix': 'na', 'root': ['r', 'd', 'f']}, 'string_pattern': 'ta|oao|na', 'vector': array([33., 10.,  7.,  8., 14., 20., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'فِعِلْ مُضَارِعْ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'aspect': 'IPFV', 'tense': 'PRS/FUT', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iia'}}
# {'word': 'mukal~afatayoni', 'pattern': {'prefix': 'mu', 'infix': ['a', '~a', 'a'], 'suffix': 'tayoni', 'root': ['k', 'l', 'f']}, 'string_pattern': 'mu|a~aa|tayoni', 'vector': array([30., 22.,  5., 23., 11., 20.,  9.,  1.,  1.,  1.,  1.,  2.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'mumohaluwona', 'pattern': {'prefix': 'mu', 'infix': ['o', 'a', 'u'], 'suffix': 'wona', 'root': ['m', 'h', 'l']}, 'string_pattern': 'mu|oau|wona', 'vector': array([30., 24.,  7., 26., 14., 23., 12.,  1.,  1.,  1.,  1.,  9.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': '(IV) tsulatsy'}}
# {'word': 'marokuwobatayoni', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'a'], 'suffix': 'tayoni', 'root': ['r', 'k', 'b']}, 'string_pattern': 'ma|ouwoa|tayoni', 'vector': array([29., 10.,  7., 22.,  9.,  2.,  9.,  1.,  1.,  1.,  1.,  2.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمَا', 'msd': {'POS': 'N', 'NUM': 'DU', 'Verb Form': 'Iia'}}
# {'word': 'xalaqa', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'a'], 'suffix': '', 'root': ['x', 'l', 'q']}, 'string_pattern': '|aaa|', 'vector': array([ 1.,  7.,  5., 23., 14., 21.,  9.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مَاضِ', 'pron': 'هُوَ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '3', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': 'Iau'}}
# {'word': 'naADijuwona', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'u'], 'suffix': 'wona', 'root': ['n', 'D', 'j']}, 'string_pattern': '|aAiu|wona', 'vector': array([ 1., 25.,  4., 15., 15.,  5., 12.,  1.,  1.,  1.,  1.,  9.]), 'wazan': 'Iia', 'wazan_predict': 'Iia', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iia'}}
# {'word': 'qal~abonaA', 'pattern': {'prefix': '', 'infix': ['a', '~a', 'o'], 'suffix': 'naA', 'root': ['q', 'l', 'b']}, 'string_pattern': '|a~ao|naA', 'vector': array([ 1., 21.,  5., 23., 11.,  2., 11.,  1.,  1.,  1.,  1., 13.]), 'wazan': '(II) tsulatsy', 'wazan_predict': '(II) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'نَحْنُ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '1', 'NUM': 'PL', 'Verb Form': '(II) tsulatsy'}}
# {'word': 'musotabo$arN', 'pattern': {'prefix': 'musota', 'infix': ['o', 'a', 'N'], 'suffix': '', 'root': ['b', '$', 'r']}, 'string_pattern': 'musota|oaN|', 'vector': array([ 8.,  2.,  7., 13., 14., 10.,  8.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(X) tsulatsy', 'wazan_predict': '(X) tsulatsy', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(X) tsulatsy'}}
# {'word': 'haAlikuwona', 'pattern': {'prefix': '', 'infix': ['aA', 'i', 'u'], 'suffix': 'wona', 'root': ['h', 'l', 'k']}, 'string_pattern': '|aAiu|wona', 'vector': array([ 1., 26.,  4., 23., 15., 22., 12.,  1.,  1.,  1.,  1.,  9.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iai'}}
# {'word': '>adoHaDotu', 'pattern': {'prefix': '>a', 'infix': ['o', 'a', 'o'], 'suffix': 'tu', 'root': ['d', 'H', 'D']}, 'string_pattern': '>a|oao|tu', 'vector': array([25.,  8.,  7.,  6., 14., 15., 11.,  1.,  1.,  1.,  1., 24.]), 'wazan': '(IV) tsulatsy', 'wazan_predict': '(IV) tsulatsy', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنَا', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '1', 'NUM': 'SG', 'Verb Form': '(IV) tsulatsy'}}
# {'word': '>iko*ibona', 'pattern': {'prefix': '>i', 'infix': ['o', 'i', 'o'], 'suffix': 'na', 'root': ['k', '*', 'b']}, 'string_pattern': '>i|oio|na', 'vector': array([26., 22.,  7.,  9., 15.,  2., 11.,  1.,  1.,  1.,  1., 30.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'فِعِلْ الأَمرْ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iai'}}
# {'word': 'munota$irN', 'pattern': {'prefix': 'muno', 'infix': ['a', 'i', 'N'], 'suffix': '', 'root': ['t', '$', 'r']}, 'string_pattern': 'muno|aiN|', 'vector': array([17.,  3.,  5., 13., 15., 10.,  8.,  1.,  1.,  1.,  1.,  1.]), 'wazan': '(VII) tsulatsy', 'wazan_predict': '(VII) tsulatsy', 'tow': 'اِسِمْ فَاعِلْ', 'pron': 'هُوَ', 'msd': {'POS': 'N', 'NUM': 'SG', 'GEN': 'MASC', 'Verb Form': '(VII) tsulatsy'}}
# {'word': 'laAtataSad~aquwoA', 'pattern': {'prefix': 'laAtata', 'infix': ['a', '~a', 'u'], 'suffix': 'woA', 'root': ['S', 'd', 'q']}, 'string_pattern': 'laAtata|a~au|woA', 'vector': array([ 4., 14.,  5.,  8., 11., 21., 12.,  1.,  1.,  1.,  1., 11.]), 'wazan': '(V) tsulatsy', 'wazan_predict': '(V) tsulatsy', 'tow': 'فِعِلْ النَهْيِ', 'pron': 'أَنْتُمْ', 'msd': {'POS': 'V', 'mood': 'IMP', 'PER': '2', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': '(V) tsulatsy'}}
# {'word': 'maforuwoDiyona', 'pattern': {'prefix': 'ma', 'infix': ['o', 'uwo', 'i'], 'suffix': 'yona', 'root': ['f', 'r', 'D']}, 'string_pattern': 'ma|ouwoi|yona', 'vector': array([29., 20.,  7., 10.,  9., 15., 10.,  1.,  1.,  1.,  1.,  8.]), 'wazan': 'Iai', 'wazan_predict': 'Iai', 'tow': 'اِسِمْ مَفْعُوْلْ', 'pron': 'هُمْ', 'msd': {'POS': 'N', 'NUM': 'PL', 'GEN': 'MASC', 'Verb Form': 'Iai'}}
# {'word': 'qanaTotun~a', 'pattern': {'prefix': '', 'infix': ['a', 'a', 'o'], 'suffix': 'tun~a', 'root': ['q', 'n', 'T']}, 'string_pattern': '|aao|tun~a', 'vector': array([ 1., 21.,  5., 25., 14., 16., 11.,  1.,  1.,  1.,  1.,  3.]), 'wazan': 'Iau', 'wazan_predict': 'Iau', 'tow': 'فِعِلْ مَاضِ', 'pron': 'أَنْتُنَّ', 'msd': {'POS': 'V', 'aspect': 'PFV', 'tense': 'PST', 'PER': '2', 'NUM': 'PL', 'GEN': 'FEM', 'Verb Form': 'Iau'}}
# {'word': '>a$oxaSu', 'pattern': {'prefix': '>a', 'infix': ['o', 'a', 'u'], 'suffix': '', 'root': ['$', 'x', 'S']}, 'string_pattern': '>a|oau|', 'vector': array([25., 13.,  7.,  7., 14., 14., 12.,  1.,  1.,  1.,  1.,  1.]), 'wazan': 'Iaa', 'wazan_predict': '(IV) tsulatsy', 'msd_predict': {'Verb Form': '(IV) tsulatsy'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-c735a82135a1> in <module>
#       7         dataGabung.append([buckwalter.untransliterate(x['word']),json.dumps(x['msd']),x['tow'],x['pron'],x['wazan'],x['wazan_predict']])
#       8     else:
# ----> 9         dataGabung.append([buckwalter.untransliterate(x['word']),json.dumps(x['msd']),'','',x['wazan'],x['wazan_predict']])
#      10
#      11
#
# KeyError: 'msd'

# %%
import json

dataGabungGagal = []
for x in dataGagal:
    if 'tow' in x:
        dataGabungGagal.append([buckwalter.untransliterate(x['word']),json.dumps(x['msd']),x['tow'],x['pron'],x['wazan'],x['wazan_predict']])
    else:
        dataGabungGagal.append([buckwalter.untransliterate(x['word']),json.dumps(x['msd']),'','',x['wazan'],x['wazan_predict']])

# %%
df = pd.DataFrame(data=dataGabung,  columns=["Word","MSD","Type of Word","Pronoun","wazan","wazan predict"])
df.to_excel("Hasil.xlsx")

# %%
df = pd.DataFrame(data=dataGabungGagal,  columns=["Word","MSD","Type of Word","Pronoun","wazan","wazan predict"])
df.to_excel("Hasil Gagal.xlsx")
